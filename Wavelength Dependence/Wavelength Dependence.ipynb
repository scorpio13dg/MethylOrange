# %%
from GushuePhotodecomp import *
# Out:
# Analysis performed using Photodecomposotion Analysis Version 3.0 Created by Niall Gushue
#
#       Version 3.0
#       - Major overhaul to organization

# %%
Decomp_385_450_1 = Experiment('385 LED USR 450 30mg 6-28-24 copy.xlsx', 
                        [14.00000],
                        [14.03000],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_385_AR_1 = Experiment('385 LED USR AR 30mg 6-13-24 copy.xlsx', 
                        [14.00000],
                        [14.03000],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_410_450_1 = Experiment('410 LED USR 450 30mg 6-28-24.xlsx', 
                        [14.00000],
                        [14.03000],
                        LED_wavelength = 410,
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_455_450_1 = Experiment('455 LED USR 450 30mg 6-28-24.xlsx', 
                        [14.00000],
                        [14.03000],
                        LED_wavelength = 455,
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_410_AR_1 = Experiment('410 LED USR AR 30mg 7-1-24.xlsx', 
                        [14.00000],
                        [14.03000],
                        LED_wavelength = 410,
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_455_AR_1 = Experiment('455 LED USR AR 30mg 7-1-24.xlsx', 
                        [14.00000],
                        [14.03000],
                        LED_wavelength = 455,
                        times = [0, 5, 15, 35, 75],
                        avg = True)
# Out:
# The Catalyst Mass is 29.99999999999936 +/- 0.0 mg
# The Initial Rate Constant is: 3.22e-07
# The Catalyst Mass is 29.99999999999936 +/- 0.0 mg
# The Initial Rate Constant is: 3.96e-07
# The Catalyst Mass is 29.99999999999936 +/- 0.0 mg
# The Initial Rate Constant is: 8.43e-08
# The Catalyst Mass is 29.99999999999936 +/- 0.0 mg
# The Initial Rate Constant is: 3.55e-08
# The Catalyst Mass is 29.99999999999936 +/- 0.0 mg
# The Initial Rate Constant is: 2.15e-07
# The Catalyst Mass is 29.99999999999936 +/- 0.0 mg
# The Initial Rate Constant is: 3.55e-08

# %% [markdown]
# # Decomposition Spectra

# %% [markdown]
# ## USR AR

# %% [markdown]
# ### 385 nm

# %%
Decomp_385_AR_1.plotdecomp()

# %% [markdown]
# ## USR 450

# %% [markdown]
# ### 385 nm

# %%
Decomp_385_450_1.plotdecomp(ylim_max = 0.9)

# %% [markdown]
# ### 410 nm

# %%
Decomp_410_450_1.plotdecomp()

# %% [markdown]
# ### 455 nm

# %%
Decomp_455_450_1.plotdecomp()

# %% [markdown]
# # Concentration vs Time

# %% [markdown]
# ## USR AR

# %% [markdown]
# ### 385 nm

# %%
Decomp_385_AR_1.compare_fit_quality()
Decomp_385_AR_1.find_linear_rate_constant()
Decomp_385_AR_1.plot_linearfit()
Decomp_385_AR_1.plot_ratetime(label = '385 nm', plot_title = 'USR AR 385nm 30mg Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# linear fit better
# linear chi squared: 4.16e-06	 exponential chi squared: 7.48e-06
# The linear rate constant is: 3.958e-07 +/- 5.94%
# The Linear Fit Equation is: Conc = -3.96e-07*t + 2.79e-05

# %% [markdown]
# ### 410 nm

# %%
Decomp_410_AR_1.compare_fit_quality()
Decomp_410_AR_1.find_linear_rate_constant()
Decomp_410_AR_1.plot_linearfit()
Decomp_410_AR_1.plot_ratetime(label = '385 nm', plot_title = 'USR AR 385nm 30mg Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# linear fit better
# linear chi squared: 2.55e-06	 exponential chi squared: 3.69e-06
# The linear rate constant is: 2.154e-07 +/- 0.37%
# The Linear Fit Equation is: Conc = -2.15e-07*t + 3.01e-05

# %% [markdown]
# ### 455 nm

# %%
Decomp_455_AR_1.compare_fit_quality()
Decomp_455_AR_1.find_linear_rate_constant()
Decomp_455_AR_1.plot_linearfit()
Decomp_455_AR_1.plot_ratetime(label = '385 nm', plot_title = 'USR AR 385nm 30mg Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# exponential fit better
# linear chi squared: 2.97e-06	 exponential chi squared: 2.44e-06
# The linear rate constant is: 1.010e-07 +/- 2.35%
# The Linear Fit Equation is: Conc = -1.01e-07*t + 3.37e-05

# %% [markdown]
# ## USR 450

# %% [markdown]
# ### 385 nm

# %%
Decomp_385_450_1.compare_fit_quality()
Decomp_385_450_1.find_exp_rate_constant()
Decomp_385_450_1.plot_expfit()
Decomp_385_450_1.plot_ratetime(label = '385 nm', plot_title = 'USR 450 385nm 30mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 6.23e-05	 exponential chi squared: 1.81e-06
# The exponential rate constant is: 3.236e-02 +/- 6.53%
# The Exponential Fit Equation is: Conc = 3.23e-05 * exp(-3.24e-02*t)

# %% [markdown]
# ### 410 nm

# %%
Decomp_410_450_1.compare_fit_quality()
Decomp_410_450_1.find_exp_rate_constant()
Decomp_410_450_1.plot_expfit()
Decomp_410_450_1.plot_ratetime(label = '410 nm', plot_title = 'USR 450 410nm 30mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 7.64e-07	 exponential chi squared: 1.89e-07
# The exponential rate constant is: 7.885e-03 +/- 1.87%
# The Exponential Fit Equation is: Conc = 3.27e-05 * exp(-7.88e-03*t)

# %% [markdown]
# ### 455 nm

# %%
Decomp_455_450_1.compare_fit_quality()
Decomp_455_450_1.find_exp_rate_constant()
Decomp_455_450_1.plot_expfit()
Decomp_455_450_1.plot_ratetime(label = '455 nm', plot_title = 'USR 450 455nm 30mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 2.97e-06	 exponential chi squared: 2.44e-06
# The exponential rate constant is: 3.254e-03 +/- 2.03%
# The Exponential Fit Equation is: Conc = 3.30e-05 * exp(-3.25e-03*t)

# %% [markdown]
# # Wavelength Dependence

# %% [markdown]
# ## USR AR

# %% [markdown]
# ### Zeroth Order Plot

# %%
experiment_set = Decomp_385_AR_1, Decomp_410_AR_1, Decomp_455_AR_1
wavelength_dependence_of_rate_constant(
    experiment_set, rate_order = 0, label = 'USR AR', 
    plot_title = 'Wavelength Dependence of USR AR with 30mg Mass \n Fitted with Zeroth Order Rate Constant')

# %% [markdown]
# ### First Order Plot

# %%
experiment_set = Decomp_385_AR_1, Decomp_410_AR_1, Decomp_455_AR_1
wavelength_dependence_of_rate_constant(
    experiment_set, rate_order = 1, label = 'USR AR', 
    plot_title = 'Wavelength Dependence of USR AR with 30mg Mass \n Fitted with First Order Rate Constant')

# %% [markdown]
# ### Initial Rate Plot

# %%
experiment_set = Decomp_385_AR_1, Decomp_410_AR_1, Decomp_455_AR_1
wavelength_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'USR AR', 
    plot_title = 'Wavelength Dependence of USR AR with 30mg Mass \n Fitted with Initial Rate')

# %% [markdown]
# ## USR 450

# %% [markdown]
# ### Zeroth Order Plot

# %%
experiment_set = Decomp_385_450_1, Decomp_410_450_1, Decomp_455_450_1
wavelength_dependence_of_rate_constant(
    experiment_set, rate_order = 0, label = 'USR 450', plot_title = 'Wavelength Dependence of USR 450 with 30mg Mass \n Fitted with Zeroth Order Rate Constant')

# %% [markdown]
# ### First Order Plot

# %%
experiment_set = Decomp_385_450_1, Decomp_410_450_1, Decomp_455_450_1
wavelength_dependence_of_rate_constant(
    experiment_set, rate_order = 1, label = 'USR 450',
    plot_title = 'Wavelength Dependence of USR 450 with 30mg Mass \n Fitted with First Order Rate Constant')

# %% [markdown]
# ### Initial Rate Plot

# %%
experiment_set = Decomp_385_450_1, Decomp_410_450_1, Decomp_455_450_1
wavelength_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'USR 450', 
    plot_title = 'Wavelength Dependence of USR 450 with 30mg Mass \n Fitted with Initial Rate')

# %% [markdown]
# # Comparison of Wavelength Dependence of USR AR and USR 450

# %% [markdown]
# ## Override

# %%
Decomp_385_450_1.find_initial_rate_constant(override = 1, exp_estimate = 1)
Decomp_410_450_1.find_initial_rate_constant(override = 1, exp_estimate = 1)
Decomp_455_450_1.find_initial_rate_constant(override = 1, exp_estimate = 1)

Decomp_385_AR_1.find_initial_rate_constant(override = 0, exp_estimate = 1)
Decomp_410_AR_1.find_initial_rate_constant(override = 0, exp_estimate = 1)
Decomp_455_AR_1.find_initial_rate_constant(override = 0, exp_estimate = 1)
# Out:
# The Initial Rate Constant is: 9.66e-07
# The Initial Rate Constant is: 2.53e-07
# The Initial Rate Constant is: 1.07e-07
# The Initial Rate Constant is: 3.96e-07
# The Initial Rate Constant is: 2.15e-07
# The Initial Rate Constant is: 1.01e-07

# %% [markdown]
# ## Comparison Plot

# %%
experiment_set = Decomp_385_AR_1, Decomp_410_AR_1, Decomp_455_AR_1
wavelength_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'USR AR', 
    plot_title = 'Wavelength Dependence of USR AR with 30mg Mass \n Fitted with Initial Rate')


experiment_set = Decomp_385_450_1, Decomp_410_450_1, Decomp_455_450_1
wavelength_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'USR 450', 
    plot_title = '')

plt.axvline(385, label = 'Band Gap', color = 'Pink')

plt.legend()
