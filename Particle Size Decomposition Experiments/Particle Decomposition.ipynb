# %%
from GushuePhotodecomp import *
# Out:
# Analysis performed using Photodecomposotion Analysis Version 3.0 Created by Niall Gushue
#
#       Version 3.0
#       - Major overhaul to organization

# %% [markdown]
# # Read in Particle Size Data

# %%
Decomp_75_AA = Experiment('385 LED AA 75 Micron 25mg 7-22-24.xlsx', 
                        [30.34190,30.34181,30.34185,30.34190,30.34193],
                        [30.36707,30.36716,30.36715,30.36704,30.36712],
                        times = [0, 5, 15, 35, 75],
                        particle_size = 75,
                        avg = True)

Decomp_75to106_AA = Experiment('385 LED AA 75-106 Micron 25mg 7-22-24.xlsx', 
                        [30.34597,30.34526,30.34522,30.34518,30.34501],
                        [30.36976,30.36977,30.36974,30.36960,30.36974],
                        times = [0, 5, 15, 35, 75,95],
                        particle_size = 90.5,
                        avg = True)

Decomp_106to150_AA = Experiment('385 LED AA 106-150 Micron 25mg 7-22-24.xlsx', 
                        [30.34154,30.34168,30.34165,30.34166,30.34165],
                        [30.36692,30.36706,30.36708,30.36712,30.36706],
                        times = [0, 5, 15, 35, 75,115],
                        particle_size = 128,
                        avg = True)

Decomp_150to250_AA = Experiment('385 LED AA 150-250 Micron 25mg 7-22-24.xlsx', 
                        [30.34190,30.34181,30.34185,30.34190,30.34193],
                        [30.36707,30.36716,30.36715,30.36704,30.36712],
                        times = [0, 5, 15, 35, 75],
                        particle_size = 200,
                        avg = True)

Decomp_250to300_AA = Experiment('385 LED AA 250-300 Micron 25mg 7-22-24.xlsx', 
                        [30.34083,30.34106,30.34111,30.34110,30.34111],
                        [30.36643,30.36637,30.36640,30.36641,30.36645],
                        times = [0, 5, 15, 35, 75],
                        particle_size = 275,
                        avg = True)

Decomp_300_AA = Experiment('385 LED AA 300 Micron 25mg 7-22-24.xlsx', 
                        [30.34083,30.34106,30.34111,30.34110,30.34111],
                        [30.36643,30.36637,30.36640,30.36641,30.36645],
                        times = [0, 5, 15, 35, 75],
                        particle_size = 300,
                        avg = True)
# Out:
# The Catalyst Mass is 25.22999999999911 +/- 0.08074651695241641 mg
# The Initial Rate Constant is: 2.62e-07
# The Catalyst Mass is 24.393999999999494 +/- 0.3186596930905661 mg
# The Initial Rate Constant is: 1.30e-07
# The Catalyst Mass is 25.411999999999324 +/- 0.03059411708118813 mg
# The Initial Rate Constant is: 1.92e-07
# The Catalyst Mass is 25.22999999999911 +/- 0.08074651695241641 mg
# The Initial Rate Constant is: 4.67e-08
# The Catalyst Mass is 25.369999999999493 +/- 0.11610340219028406 mg
# The Initial Rate Constant is: 1.75e-07
# The Catalyst Mass is 25.369999999999493 +/- 0.11610340219028406 mg
# The Initial Rate Constant is: 4.18e-08

# %% [markdown]
# # Process Particle Size Data

# %% [markdown]
# ## Photodecomposition

# %% [markdown]
# ### 75 µm

# %%
Decomp_75_AA.plotdecomp()

# %% [markdown]
# ### 75 - 106 µm

# %%
Decomp_75to106_AA.plotdecomp()

# %% [markdown]
# ### 106 - 150 µm

# %%
Decomp_106to150_AA.plotdecomp()

# %% [markdown]
# ### 150 - 250 µm

# %%
Decomp_150to250_AA.plotdecomp()

# %%
Decomp_250to300_AA.plotdecomp()

# %% [markdown]
# ### 300 µm

# %%
Decomp_300_AA.plotdecomp()

# %% [markdown]
# ## Concentration vs Time

# %% [markdown]
# ### 75 µm: Zeroth Order Linear Fit

# %%
Decomp_75_AA.compare_fit_quality()
Decomp_75_AA.find_linear_rate_constant()
Decomp_75_AA.plot_linearfit()
Decomp_75_AA.plot_ratetime(label = '75µm', plot_title = 'AA 75µm Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# exponential fit better
# linear chi squared: inf	 exponential chi squared: inf
# The linear rate constant is: 1.503e-07 +/- 7.19%
# The Linear Fit Equation is: Conc = -1.50e-07*t + 3.28e-05

# %% [markdown]
# ### 75 - 106 µm: Zeroth Order Linear Fit

# %%
Decomp_75to106_AA.compare_fit_quality()
Decomp_75to106_AA.find_linear_rate_constant()
Decomp_75to106_AA.plot_linearfit()
Decomp_75to106_AA.plot_ratetime(label = '75µm', plot_title = 'AA 75 - 106µm Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# linear fit better
# linear chi squared: 2.14e-07	 exponential chi squared: 7.83e-07
# The linear rate constant is: 1.300e-07 +/- 1.81%
# The Linear Fit Equation is: Conc = -1.30e-07*t + 3.11e-05

# %% [markdown]
# ### 106 - 150 µm: Zeroth Order Linear Fit

# %%
Decomp_106to150_AA.compare_fit_quality()
Decomp_106to150_AA.find_linear_rate_constant()
Decomp_106to150_AA.plot_linearfit()
Decomp_106to150_AA.plot_ratetime(label = '106 - 150µm', plot_title = 'AA 75µm Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# linear fit better
# linear chi squared: 2.77e-06	 exponential chi squared: 3.32e-05
# The linear rate constant is: 2.845e-07 +/- 0.69%
# The Linear Fit Equation is: Conc = -2.84e-07*t + 3.18e-05

# %% [markdown]
# ### 150 - 250 µm: Zeroth Order Linear Fit

# %%
Decomp_150to250_AA.compare_fit_quality()
Decomp_150to250_AA.find_linear_rate_constant()
Decomp_150to250_AA.plot_linearfit()
Decomp_150to250_AA.plot_ratetime(label = '150 - 250µm', plot_title = 'AA 150 - 250µm Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# exponential fit better
# linear chi squared: 7.44e-08	 exponential chi squared: 3.04e-08
# The linear rate constant is: 1.174e-07 +/- 2.60%
# The Linear Fit Equation is: Conc = -1.17e-07*t + 3.10e-05

# %% [markdown]
# ### 250 - 300 µm: Zeroth Order Linear Fit

# %%
Decomp_250to300_AA.compare_fit_quality()
Decomp_250to300_AA.find_linear_rate_constant()
Decomp_250to300_AA.plot_linearfit()
Decomp_250to300_AA.plot_ratetime(label = '250 - 300µm', plot_title = 'AA 250 - 300µm Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# linear fit better
# linear chi squared: 5.24e-07	 exponential chi squared: 1.05e-06
# The linear rate constant is: 1.748e-07 +/- 3.70%
# The Linear Fit Equation is: Conc = -1.75e-07*t + 3.27e-05

# %% [markdown]
# ### 300 µm: Zeroth Order Linear Fit

# %%
Decomp_300_AA.compare_fit_quality()
Decomp_300_AA.find_linear_rate_constant()
Decomp_300_AA.plot_linearfit()
Decomp_300_AA.plot_ratetime(label = '300µm', plot_title = 'AA 300µm Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# linear fit better
# linear chi squared: 4.29e-08	 exponential chi squared: 6.60e-08
# The linear rate constant is: 4.184e-08 +/- 0.35%
# The Linear Fit Equation is: Conc = -4.18e-08*t + 3.16e-05

# %% [markdown]
# ## Particle Size Dependence

# %%
experiment_set = Decomp_75_AA,Decomp_75to106_AA,Decomp_106to150_AA,Decomp_150to250_AA,Decomp_250to300_AA,Decomp_300_AA
particle_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'AA', plot_title = 'Particle Size AA with 385nm Light ')
