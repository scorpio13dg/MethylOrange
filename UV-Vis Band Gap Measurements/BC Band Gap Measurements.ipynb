# %%
from kiethley import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Analysis performed using kiethley macros version 2.2

# %% [markdown]
# # Read in UV-Vis Spectra

# %%
KBr_1 = spectrum('7-1-24 KBr 1.txt')
KBr_2 = spectrum('7-1-24 KBr 2.txt')
KBr_3 = spectrum('7-1-24 KBr 3.txt')

BC_1 = spectrum('6-21-24 BC 2.txt')
BC_1_KBr = spectrum('6-21-24 KBr 2.txt')

BC_400_1 = spectrum('7-1-24 BC 400 1.txt', first_step_threshold= 10)
BC_400_2 = spectrum('7-1-24 BC 400 2.txt', first_step_threshold= 10)
BC_400_3 = spectrum('7-1-24 BC 400 3.txt', first_step_threshold= 10)

KBr_4 = spectrum('7-1-24 KBr 4.txt')
KBr_5 = spectrum('7-1-24 KBr 5.txt')
KBr_6 = spectrum('7-1-24 KBr 6.txt')

BC_PB_1 = spectrum('7-1-24 BC PB 1.txt', first_step_threshold= 10)
BC_PB_2 = spectrum('7-1-24 BC PB 2.txt', first_step_threshold= 10)
BC_PB_3 = spectrum('7-1-24 BC PB 3.txt', first_step_threshold= 10)

USR_AR_1 = spectrum('6-18-24 USR-AR 1.txt', first_step_threshold= 5) #Doesn't work??
KBr_1_USR_AR = spectrum('6-18-24 KBr 1.txt')

USR_450_4 = spectrum('6-20-24 USR 450 4.txt', first_step_threshold= 50)
KBr_4_USR_450 = spectrum('6-20-24 KBr 4.txt')

# %% [markdown]
# # Process Data

# %% [markdown]
# ## Plot BC 400

# %%
KBr_1.plotspectrum(Label = 'KBr 1')
KBr_2.plotspectrum(Label = 'KBr 2')
KBr_3.plotspectrum(Label = 'KBr 3')

BC_400_1.plotspectrum(Label = 'BC 400 1')
BC_400_2.plotspectrum(Label = 'BC 400 2')
BC_400_3.plotspectrum(Label = 'BC 400 3')

plt.legend()

# %% [markdown]
# ## Plot BC Post BET

# %%
KBr_4.plotspectrum(Label = 'KBr 4')
KBr_5.plotspectrum(Label = 'KBr 5')
KBr_6.plotspectrum(Label = 'KBr 6')

BC_PB_1.plotspectrum(Label = 'BC PB 1')
BC_PB_2.plotspectrum(Label = 'BC PB 2')
BC_PB_3.plotspectrum(Label = 'BC PB 3')

plt.legend()

# %% [markdown]
# ## Checking Steps

# %% [markdown]
# ### KBr 1

# %%
KBr_1.plotsteps()

# %% [markdown]
# ### KBr 2

# %%
KBr_2.plotsteps()

# %% [markdown]
# ### KBr 3

# %%
KBr_3.plotsteps()

# %% [markdown]
# ### BC 400 1

# %%
BC_400_1.plotsteps()

# %% [markdown]
# ### BC 400 2

# %%
BC_400_2.plotsteps()

# %% [markdown]
# ### BC 400 3

# %%
BC_400_3.plotsteps()

# %% [markdown]
# ### KBr 4

# %%
KBr_4.plotsteps()

# %% [markdown]
# ### KBr 5

# %%
KBr_5.plotsteps()

# %% [markdown]
# ### KBr 6

# %%
KBr_6.plotsteps()

# %% [markdown]
# ### BC PB 1

# %%
BC_PB_1.plotsteps()

# %% [markdown]
# ## BC 400 Band Gap

# %% [markdown]
# ### BC 400°C 1

# %%
BC_400_1.KM_transform(KBr_1)
#BC_400_1.plotKM()
BC_400_1.tauc_transform()
BC_400_1.plottauc()

plt.title('Tauc Plot BC 400°C Band Gap = 3.22 eV')
# Out:
# Text(0.5, 1.0, 'Tauc Plot BC 400°C Band Gap = 3.22 eV')

# %%
BC_400_1.tauc_fit([2.5,2.7],[3.3,3.5])
# Out:
# band gap: 3.22 eV

# %% [markdown]
# ### BC 400 2

# %%
BC_400_2.KM_transform(KBr_2)
#BC_400_2.plotKM()
BC_400_2.tauc_transform()
BC_400_2.plottauc()

plt.title('Tauc Plot BC 400 2')
# Out:
# Text(0.5, 1.0, 'Tauc Plot BC 400 2')

# %%
BC_400_2.tauc_fit([2.5,2.7],[3.3,3.5])
# Out:
# band gap: 3.22 eV

# %% [markdown]
# ### BC 400 3

# %%
BC_400_3.KM_transform(KBr_3)
#BC_400_3.plotKM()
BC_400_3.tauc_transform()
BC_400_3.plottauc()

plt.title('Tauc Plot BC 400 1')
# Out:
# Text(0.5, 1.0, 'Tauc Plot BC 400 1')

# %%
BC_400_3.tauc_fit([2.3,2.5],[3.3,3.5])
# Out:
# band gap: 3.21 eV

# %% [markdown]
# ## BC Post BET Band Gap

# %% [markdown]
# ### BC PB 1

# %%
BC_PB_1.KM_transform(KBr_4)
#BC_400_1.plotKM()
BC_PB_1.tauc_transform()
BC_PB_1.plottauc()

plt.title('Tauc Plot BC Post BET Band Gap = 3.26 eV')
# Out:
# Text(0.5, 1.0, 'Tauc Plot BC Post BET Band Gap = 3.26 eV')

# %%
BC_PB_1.tauc_fit([2.3,2.5],[3.3,3.8])
# Out:
# band gap: 3.26 eV

# %% [markdown]
# ### BC PB 2

# %%
BC_PB_2.KM_transform(KBr_5)
#BC_400_1.plotKM()
BC_PB_2.tauc_transform()
BC_PB_2.plottauc()

plt.title('Tauc Plot BC PB 2')
# Out:
# Text(0.5, 1.0, 'Tauc Plot BC PB 2')

# %%
BC_PB_2.tauc_fit([2.3,2.5],[3.3,3.8])
# Out:
# band gap: 3.26 eV

# %% [markdown]
# ### BC PB 3

# %%
BC_PB_3.KM_transform(KBr_6)
#BC_400_1.plotKM()
BC_PB_3.tauc_transform()
BC_PB_3.plottauc()

plt.title('Tauc Plot BC PB 2')
# Out:
# Text(0.5, 1.0, 'Tauc Plot BC PB 2')

# %%
BC_PB_2.tauc_fit([2.3,2.5],[3.3,3.8])
# Out:
# band gap: 3.26 eV

# %% [markdown]
# ## BC Original

# %% [markdown]
# ### BC 1

# %%
BC_1.KM_transform(BC_1_KBr)
#BC_400_1.plotKM()
BC_1.tauc_transform()
BC_1.plottauc()

plt.title('Tauc Plot BC 1')
# Out:
# Text(0.5, 1.0, 'Tauc Plot BC 1')

# %%
BC_1.tauc_fit([2,2.3],[3.1,3.2])
# Out:
# band gap: 3.02 eV

# %% [markdown]
# ## USR AR

# %% [markdown]
# ### USR AR 1

# %%
USR_AR_1.KM_transform(KBr_1_USR_AR)

USR_AR_1.tauc_transform()
USR_AR_1.plottauc()

plt.title('Tauc Plot USR AR')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR AR')

# %%
USR_AR_1.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.25 eV

# %% [markdown]
# ## USR 450

# %% [markdown]
# ### USR 450 4

# %%
USR_450_4.KM_transform(KBr_4_USR_450)

USR_450_4.tauc_transform()
USR_450_4.plottauc()

plt.title('Tauc Plot USR 450 4')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450 4')

# %%
USR_450_4.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.27 eV

# %% [markdown]
# # KM Plots

# %%
plt.plot(BC_PB_1.wavelength,BC_PB_1.KM/4.77, label = 'BC Post BET Band Gap: 3.26eV')
plt.plot(BC_400_1.wavelength,BC_400_1.KM/4.85, label = 'BC 400 Band Gap: 3.22eV')
plt.plot(BC_1.wavelength,BC_1.KM/8.74, label = 'BC Fine Band Gap: 3.01eV')
plt.title('KM Plots of BC Catalysts')
plt.legend()
plt.xlabel('Wavelength (nm)')
plt.ylabel('KM Absorbance')
# Out:
# Text(0, 0.5, 'KM Absorbance')

# %%
plt.plot(USR_450_4.wavelength,USR_450_4.KM/5.2, label = 'USR 450 Band Gap: 3.27eV')
plt.plot(BC_PB_1.wavelength,BC_PB_1.KM/4.77, label = 'BC Post BET Band Gap: 3.26eV')
plt.plot(USR_AR_1.wavelength,USR_AR_1.KM/5, label = 'USR AR Band Gap: 3.25eV')
plt.plot(BC_400_1.wavelength,BC_400_1.KM/4.85, label = 'BC 400 Band Gap: 3.22eV')
plt.plot(BC_1.wavelength,BC_1.KM/8.74, label = 'BC Fine Band Gap: 3.01eV')
plt.title('KM Plots of Photocatalysts Catalysts')
plt.legend()
plt.xlabel('Wavelength (nm)')
plt.ylabel('KM Absorbance')
# Out:
# Text(0, 0.5, 'KM Absorbance')

# %%
plt.plot(USR_450_4.wavelength,USR_450_4.KM/5.2, label = 'USR 450 Band Gap: 3.27eV')
plt.plot(USR_AR_1.wavelength,USR_AR_1.KM/5, label = 'USR AR Band Gap: 3.25eV')
plt.title('KM Plots of USR Catalysts')
plt.legend()
plt.xlabel('Wavelength (nm)')
plt.ylabel('KM Absorbance')
# Out:
# Text(0, 0.5, 'KM Absorbance')

# %%
BC_PB_1.plotspectrum(Label = 'BC PB 1')
BC_400_1.plotspectrum(Label = 'BC 400 1')
#BC_1.plotspectrum(Label = 'BC 1')
#KBr_1.plotspectrum(Label = 'KBr 1')

plt.xlim([400, 500])
plt.ylim([6, 9])
plt.legend()

# %%
USR_AR_1.plotspectrum(Label = 'USR AR')
USR_450_4.plotspectrum(Label = 'USR 450')
KBr_1_USR_AR.plotspectrum(Label = 'KBr')

plt.legend()

# %% [markdown]
# # Figures

# %%
plt.subplot(2, 1, 2)
USR_450_4.tauc_fit([2.7,2.8],[3.3,3.5],label = 'USR 450, Eg: 3.27eV', color = 'royalblue')
BC_PB_1.tauc_fit([2.3,2.5],[3.3,3.8],label = 'BC Post BET, Eg: 3.26eV', color = 'goldenrod')
USR_AR_1.tauc_fit([2.7,2.8],[3.3,3.5],label = 'USR AR, Eg: 3.25eV', color = 'green')
BC_400_1.tauc_fit([2.5,2.7],[3.3,3.5],label = 'BC 400, Eg: 3.22eV', color = 'red')
BC_1.tauc_fit([2,2.3],[3.1,3.2],label = 'BC Fine, Eg: 3.01eV', color = 'mediumpurple')


#USR_450_4.plottauc(Label = 'USR 450, Eg: 3.27 eV')
#BC_PB_1.plottauc(Label = 'BC PB, Eg: 3.26')
#USR_AR_1.plottauc(Label = 'USR AR, Eg: 3.25 eV')
#BC_400_1.plottauc(Label = 'BC 400, Eg: 3.22 eV')
#BC_1.plottauc(Label = 'BC, Eg: 3.01 eV')

plt.legend()
plt.xlim(2.5,4.35)
plt.ylim(0,5)

plt.subplot(2, 1, 1)
plt.tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
plt.plot(USR_450_4.wavelength,USR_450_4.KM/5.2, label = 'USR 450, Eg: 3.27eV')
plt.plot(BC_PB_1.wavelength,BC_PB_1.KM/4.77, label = 'BC Post BET, Eg: 3.26eV')
plt.plot(USR_AR_1.wavelength,USR_AR_1.KM/5, label = 'USR AR, Eg: 3.25eV')
plt.plot(BC_400_1.wavelength,BC_400_1.KM/4.85, label = 'BC 400, Eg: 3.22eV')
plt.plot(BC_1.wavelength,BC_1.KM/8.74, label = 'BC Fine, Eg: 3.01eV')
#plt.title('KM Plots of Photocatalysts Catalysts')

plt.legend()
plt.xlabel('Wavelength (nm)')
plt.ylabel('KM Absorbance')
plt.xlim(285,496)
# Out:
# band gap: 3.27 eV
# band gap: 3.26 eV
# band gap: 3.25 eV
# band gap: 3.22 eV
# band gap: 3.02 eV
# (285.0, 496.0)

# %%
plt.subplot(1,1,1)
USR_AR_1.plotspectrum(Label = 'USR AR')
USR_450_4.plotspectrum(Label = 'USR 450')
BC_1.plotspectrum(Label = 'BC')
BC_PB_1.plotspectrum(Label = 'BC PB')
BC_400_1.plotspectrum(Label = 'BC 400')
plt.legend()

plt.subplot(2, 2, 4)
plt.tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
USR_AR_1.plotspectrum(Label = 'USR AR')
USR_450_4.plotspectrum(Label = 'USR 450')
BC_1.plotspectrum(Label = 'BC')
BC_PB_1.plotspectrum(Label = 'BC PB')
BC_400_1.plotspectrum(Label = 'BC 400')
plt.xlim(280,390)
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')
