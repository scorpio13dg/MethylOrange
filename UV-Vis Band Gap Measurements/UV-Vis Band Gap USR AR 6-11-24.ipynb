# %%
from kiethley import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Analysis performed using kiethley macros version 2.2

# %%
KBr_1 = spectrum('6-11-24 KBr 1532.txt')
KBr_2 = spectrum('6-11-24 KBr 1540.txt')
KBr_3 = spectrum('6-11-24 KBr 1547.txt')

USR_AR_1 = spectrum('6-11-24 USR as-received (6-10 batch) 1609.txt')
USR_AR_2 = spectrum('6-11-24 USR as-received (6-10 batch) 1617.txt')
USR_AR_3 = spectrum('6-11-24 USR as-received (6-10 batch) 1624.txt')

KBr_New = spectrum('6-13-24 KBr.txt')
USR_AR_New_1 = spectrum('6-13-24 USR as-received (6-10 batch) 1.txt')
USR_AR_New_2 = spectrum('6-13-24 USR as-received (6-10 batch) 2.txt')
USR_AR_New_3 = spectrum('6-13-24 USR as-received (6-10 batch) 3.txt')

# %% [markdown]
# # Checking Steps

# %%
KBr_1.plotsteps()

# %%
KBr_2.plotsteps()

# %%
KBr_3.plotsteps()

# %%
USR_AR_1.plotsteps()

# %%
USR_AR_2.plotsteps()

# %%
USR_AR_3.plotsteps()

# %% [markdown]
# # Process Data

# %%
KBr_1.plotspectrum(Label = 'KBr 1')
KBr_2.plotspectrum(Label = 'KBr 2')
KBr_3.plotspectrum(Label = 'KBr 3')
USR_AR_1.plotspectrum(Label = 'USR AR 1')
USR_AR_2.plotspectrum(Label = 'USR AR 2')
USR_AR_3.plotspectrum(Label = 'USR AR 3')

plt.legend()

# %% [markdown]
# ## USR AR 1

# %%
USR_AR_1.KM_transform(KBr_1)
#USR_450_1.plotKM()
USR_AR_1.tauc_transform()
USR_AR_1.plottauc()

plt.title('Tauc Plot USR AR 1')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR AR 1')

# %%
USR_AR_1.tauc_fit([2.0,2.5],[3.3,3.5])
# Out:
# band gap: 3.32 eV

# %% [markdown]
# ## USR AR 2

# %%
USR_AR_2.KM_transform(KBr_2)
#USR_450_1.plotKM()
USR_AR_2.tauc_transform()
USR_AR_2.plottauc()

plt.title('Tauc Plot USR AR 2')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR AR 2')

# %%
USR_AR_2.tauc_fit([2.0,2.5],[3.3,3.5])
# Out:
# band gap: 3.32 eV

# %% [markdown]
# ## USR AR 3

# %%
USR_AR_3.KM_transform(KBr_3)
#USR_450_1.plotKM()
USR_AR_3.tauc_transform()
USR_AR_3.plottauc()

plt.title('Tauc Plot USR AR 3')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR AR 3')

# %%
USR_AR_3.tauc_fit([2.0,2.5],[3.3,3.5])
# Out:
# band gap: 3.33 eV

# %% [markdown]
# ## Second Day USR AR

# %%
KBr_New.plotspectrum(Label = 'KBr')
USR_AR_New_1.plotspectrum(Label = 'USR AR')
USR_AR_New_2.plotspectrum(Label = 'USR AR')
USR_AR_New_3.plotspectrum(Label = 'USR AR')

plt.legend()

# %%
USR_AR_New_1.KM_transform(KBr_New)
#USR_450_1.plotKM()
USR_AR_New_1.tauc_transform()
USR_AR_New_1.plottauc()

plt.title('Tauc Plot USR AR 1')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR AR 1')

# %%
USR_AR_New_1.tauc_fit([2.0,2.5],[3.3,3.5])
# Out:
# band gap: 3.28 eV
