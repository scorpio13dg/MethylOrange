# %%
from kiethley import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Analysis performed using kiethley macros version 2.2

# %%
KBr_1 = spectrum('KBr 1543 6-10-24.txt')
KBr_2 = spectrum('KBr 1551 6-10-24.txt')
KBr_3 = spectrum('KBr 1638 6-10-24.txt')

USR_450_1 = spectrum('USR 450 1609 6-10-24.txt')
USR_450_2 = spectrum('USR 450 1616 6-10-24.txt')
USR_450_3 = spectrum('USR 450 1625 6-10-24.txt')

# %% [markdown]
# # Checking Steps

# %%
KBr_1.plotsteps()

# %%
KBr_2.plotsteps()

# %%
KBr_3.plotsteps()

# %%
USR_450_1.plotsteps()

# %%
USR_450_2.plotsteps()

# %%
USR_450_3.plotsteps()

# %% [markdown]
# # Process Data

# %%
KBr_1.plotspectrum(Label = 'KBr 1')
KBr_2.plotspectrum(Label = 'KBr 2')
KBr_3.plotspectrum(Label = 'KBr 3')
USR_450_1.plotspectrum(Label = 'USR 450 1')
USR_450_2.plotspectrum(Label = 'USR 450 2')
USR_450_3.plotspectrum(Label = 'USR 450 3')

plt.legend()

# %% [markdown]
# ## USR 450 1

# %%
USR_450_1.KM_transform(KBr_3)
#USR_450_1.plotKM()
USR_450_1.tauc_transform()
USR_450_1.plottauc()

plt.title('Tauc Plot USR 450 Old Batch')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450 Old Batch')

# %%
USR_450_1.tauc_fit([2.0,2.5],[3.3,3.5])
# Out:
# band gap: 3.25 eV

# %% [markdown]
# ## USR 450 2

# %%
USR_450_2.KM_transform(KBr_3)
#USR_450_1.plotKM()
USR_450_2.tauc_transform()
USR_450_2.plottauc()

plt.title('Tauc Plot USR 450 2')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450 2')

# %%
USR_450_2.tauc_fit([2.0,2.5],[3.3,3.5])
# Out:
# band gap: 3.26 eV

# %% [markdown]
# ## USR 450 3

# %%
USR_450_3.KM_transform(KBr_3)
#USR_450_1.plotKM()
USR_450_3.tauc_transform()
USR_450_3.plottauc()

plt.title('Tauc Plot USR 450 3')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450 3')

# %%
USR_450_3.tauc_fit([2.0,2.5],[3.3,3.5])
# Out:
# band gap: 3.25 eV
