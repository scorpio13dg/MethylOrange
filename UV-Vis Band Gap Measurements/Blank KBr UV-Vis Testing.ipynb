# %%
from kiethley import *
import numpy as np
import matplotlib.pyplot as plt

# %%
KBr_1 = spectrum('6-13-24 KBr.txt')
KBr_2 = spectrum('6-14-24 KBr 1.txt')
#KBr_3_old = spectrum('6-14-24 KBr 2.txt')
KBr_3 = spectrum('6-14-24 KBr 3.txt')
KBr_4 = spectrum('6-14-24 KBr 4.txt')
KBr_5 = spectrum('6-14-24 KBr 5.txt')

# %% [markdown]
# # Process Data

# %%
#KBr_1.plotspectrum(Label = 'KBr 1')
KBr_2.plotspectrum(Label = 'KBr 2')
#KBr_3_old.plotspectrum(Label = 'KBr 3 old') off the graph // overloaded
KBr_3.plotspectrum(Label = 'KBr 3')
KBr_4.plotspectrum(Label = 'KBr 4')
KBr_5.plotspectrum(Label = 'KBr 5')


plt.legend()
