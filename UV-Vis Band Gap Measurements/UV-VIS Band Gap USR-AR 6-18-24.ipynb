# %%
from kiethley import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Analysis performed using kiethley macros version 2.2

# %%
KBr_1 = spectrum('6-18-24 KBr 1.txt')
KBr_2 = spectrum('6-18-24 KBr 2.txt')
KBr_3 = spectrum('6-18-24 KBr 3.txt')

USR_AR_1 = spectrum('6-18-24 USR-AR 1.txt', first_step_threshold= 5) #Doesn't work??
USR_AR_2 = spectrum('6-18-24 USR-AR 2.txt', first_step_threshold= 5)
USR_AR_3 = spectrum('6-18-24 USR-AR 3.txt', first_step_threshold= 5) #Doesn't work??

# %% [markdown]
# # USR AR Collected 6-18-24

# %% [markdown]
# ## Checking Steps

# %%
KBr_1.plotsteps()

# %%
KBr_2.plotsteps()

# %%
KBr_3.plotsteps()

# %%
USR_AR_1.plotsteps()

# %%
USR_AR_2.plotsteps()

# %%
USR_AR_3.plotsteps()

# %% [markdown]
# ## Process Data

# %%
KBr_1.plotspectrum(Label = 'KBr 1')
KBr_2.plotspectrum(Label = 'KBr 2')
KBr_3.plotspectrum(Label = 'KBr 3')


USR_AR_1.plotspectrum(Label = 'USR AR 1')
USR_AR_2.plotspectrum(Label = 'USR AR 2')
USR_AR_3.plotspectrum(Label = 'USR AR 3')

plt.title('USR AR and Background')

plt.legend()

# %% [markdown]
# ### USR AR 1

# %%
USR_AR_1.KM_transform(KBr_1)

USR_AR_1.tauc_transform()
USR_AR_1.plottauc()

plt.title('Tauc Plot USR AR')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR AR')

# %%
USR_AR_1.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.25 eV

# %% [markdown]
# ### USR AR 2

# %%
USR_AR_2.KM_transform(KBr_2)

USR_AR_2.tauc_transform()
USR_AR_2.plottauc()

plt.title('Tauc Plot USR AR 2')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR AR 2')

# %%
USR_AR_2.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.25 eV

# %% [markdown]
# ### USR AR 3

# %%
USR_AR_3.KM_transform(KBr_3)

USR_AR_3.tauc_transform()
USR_AR_3.plottauc()

plt.title('Tauc Plot USR AR 3')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR AR 3')

# %%
USR_AR_3.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.25 eV

# %% [markdown]
# # USR 450 Collected  6-20-24

# %%
KBr_1_450 = spectrum('6-20-24 KBr 1.txt')
KBr_2_450 = spectrum('6-20-24 KBr 2.txt')
KBr_3_450 = spectrum('6-20-24 KBr 3.txt')

USR_450_1 = spectrum('6-20-24 USR 450 1.txt', first_step_threshold= 10)
USR_450_2 = spectrum('6-20-24 USR 450 2.txt', first_step_threshold= 10)
USR_450_3 = spectrum('6-20-24 USR 450 3.txt', first_step_threshold= 10)

# %% [markdown]
# ## Checking Steps

# %%
KBr_1_450.plotsteps()

# %%
KBr_2_450.plotsteps()

# %%
KBr_3_450.plotsteps()

# %%
USR_450_1.plotsteps()

# %%
USR_450_2.plotsteps()

# %%
USR_450_3.plotsteps()

# %% [markdown]
# ## Process Data

# %%
KBr_1_450.plotspectrum(Label = 'KBr 1')
KBr_2_450.plotspectrum(Label = 'KBr 2')
KBr_3_450.plotspectrum(Label = 'KBr 3')

USR_450_1.plotspectrum(Label = 'USR 450 1')
USR_450_2.plotspectrum(Label = 'USR 450 2')
USR_450_3.plotspectrum(Label = 'USR 450 3')

plt.legend()
plt.title('USR 450 and Background')
# Out:
# Text(0.5, 1.0, 'USR 450 and Background')

# %% [raw]
# The USR 450 seems to be misaligned so this data is going to be remeasured

# %% [markdown]
# ### USR 450 1

# %%
USR_450_1.KM_transform(KBr_1_450)

USR_450_1.tauc_transform()
USR_450_1.plottauc()

plt.title('Tauc Plot USR 450 1')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450 1')

# %%
USR_450_1.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.27 eV

# %% [markdown]
# ### USR 450 2

# %%
USR_450_2.KM_transform(KBr_2_450)

USR_450_2.tauc_transform()
USR_450_2.plottauc()

plt.title('Tauc Plot USR 450 2')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450 2')

# %%
USR_450_2.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.27 eV

# %% [markdown]
# ### USR 450 3

# %%
USR_450_3.KM_transform(KBr_3_450)

USR_450_3.tauc_transform()
USR_450_3.plottauc()

plt.title('Tauc Plot USR 450 3')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450 3')

# %%
USR_450_3.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.28 eV

# %% [markdown]
# # USR 450 6-20-24 Remeasured

# %%
KBr_4 = spectrum('6-20-24 KBr 4.txt')
KBr_5 = spectrum('6-20-24 KBr 5.txt')
KBr_6 = spectrum('6-20-24 KBr 6.txt')

USR_450_4 = spectrum('6-20-24 USR 450 4.txt', first_step_threshold= 50)
USR_450_5 = spectrum('6-20-24 USR 450 5.txt', first_step_threshold= 5)
USR_450_6 = spectrum('6-20-24 USR 450 6.txt', first_step_threshold= 50)

# %% [markdown]
# ## Checking Steps

# %%
KBr_4.plotsteps()

# %%
KBr_5.plotsteps()

# %%
KBr_6.plotsteps()

# %%
USR_450_4.plotsteps()

# %%
USR_450_5.plotsteps()

# %% [markdown]
# ## Process Data

# %%
KBr_4.plotspectrum(Label = 'KBr 4')
#KBr_5.plotspectrum(Label = 'KBr 5')
#KBr_6.plotspectrum(Label = 'KBr 6')

USR_450_4.plotspectrum(Label = 'USR 450 4')
#USR_450_5.plotspectrum(Label = 'USR 450 5')
#USR_450_6.plotspectrum(Label = 'USR 450 6')

USR_AR_1.plotspectrum(Label = 'USR AR 1')

plt.title('USR 450 and Background')
plt.legend()

# %% [markdown]
# ### USR 450 4

# %%
USR_450_4.KM_transform(KBr_4)

USR_450_4.tauc_transform()
USR_450_4.plottauc()

plt.title('Tauc Plot USR 450 4')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450 4')

# %%
USR_450_4.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.27 eV

# %% [markdown]
# ### USR 450 5

# %%
USR_450_5.KM_transform(KBr_5)

USR_450_5.tauc_transform()
USR_450_5.plottauc()

plt.title('Tauc Plot USR 450_5')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450_5')

# %%
USR_450_5.tauc_fit([2.7,2.8],[3.3,3.5])
# Out:
# band gap: 3.27 eV

# %% [markdown]
# ### USR 450 6

# %%
USR_450_6.KM_transform(KBr_6)

USR_450_6.tauc_transform()
USR_450_6.plottauc()

plt.title('Tauc Plot USR 450 6-10-24 Batch')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450 6-10-24 Batch')

# %%
USR_450_6.tauc_fit([2.7,2.8],[3.3,3.5])
plt.title('USR 450 Fitted Tauc Plot')
# Out:
# band gap: 3.27 eV
# Text(0.5, 1.0, 'USR 450 Fitted Tauc Plot')

# %% [markdown]
# # BC Anatase

# %%
KBr_1_BC = spectrum('6-21-24 KBr 1.txt')
KBr_2_BC = spectrum('6-21-24 KBr 2.txt')
KBr_3_BC = spectrum('6-21-24 KBr 3.txt')

BC_1 = spectrum('6-21-24 BC 1.txt')
BC_2 = spectrum('6-21-24 BC 2.txt')
BC_3 = spectrum('6-21-24 BC 3.txt')

# %% [markdown]
# ## Checking Steps

# %% [markdown]
# ## Process Data

# %%
KBr_1_BC.plotspectrum(Label = 'KBr 1')
KBr_2_BC.plotspectrum(Label = 'KBr 2')
KBr_3_BC.plotspectrum(Label = 'KBr 3')

BC_1.plotspectrum(Label = 'BC 1')
BC_2.plotspectrum(Label = 'BC 2')
BC_2.plotspectrum(Label = 'BC 3')

plt.legend()
plt.title('BC and Background')
# Out:
# Text(0.5, 1.0, 'BC and Background')

# %%
BC_1.KM_transform(KBr_1_BC)

BC_1.tauc_transform()
BC_1.plottauc()

plt.title('Tauc Plot USR 450_6')
# Out:
# Text(0.5, 1.0, 'Tauc Plot USR 450_6')

# %%
BC_1.plotKM()

# %%
BC_1.tauc_fit([2.3,2.7],[3.1,3.5])
# Out:
# band gap: 3.01 eV

# %%
BC_2.KM_transform(KBr_1_BC)

BC_2.tauc_transform()
BC_2.plottauc()

plt.title('Tauc Plot BC Band Gap = 3.01 eV')
# Out:
# Text(0.5, 1.0, 'Tauc Plot BC Band Gap = 3.01 eV')

# %%
BC_2.tauc_fit([2.3,2.7],[3.1,3.5])
# Out:
# band gap: 3.01 eV

# %%
plt.plot(USR_AR_1.wavelength,USR_AR_1.KM, label = 'AR')
plt.plot(USR_450_1.wavelength,USR_450_1.KM, label = '450')
plt.legend()

# %% [markdown]
# # KM Plots

# %%
BC_1.plotKM()

# %%
USR_AR_1.plotKM()

# %%
plt.plot(USR_450_4.wavelength,USR_450_4.KM, label = 'USR 450')
plt.plot(USR_AR_1.wavelength,USR_AR_1.KM, label = 'USR AR')
plt.legend()
