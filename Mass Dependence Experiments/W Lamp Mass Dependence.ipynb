# %%
from GushuePhotodecomp import *
# Out:
# Analysis performed using Photodecomposotion Analysis Version 3.0 Created by Niall Gushue
#
#       Version 3.0
#       - Major overhaul to organization

# %% [markdown]
# # Read in Old Lamp USR AR

# %%
Decomp_AROW_6mg_1 = Experiment('LB USR AR 6mg 11-16-23.xlsx', 
                        [20.00000],
                        [20.00600],
                        times = [0, 5, 15, 35, 75,115],
                        avg = False)

Decomp_AROW_12mg_1 = Experiment('LB USR AR 12mg 10-13-23.xlsx', 
                        [20.00000],
                        [20.01200],
                        times = [0, 5, 15, 35, 75,115],
                        avg = False)

Decomp_AROW_23mg_1 = Experiment('LB USR AR 23mg 11-9-23.xlsx', 
                        [20.00000],
                        [20.02300],
                        times = [0, 5, 15, 35, 75,115],
                        avg = False)
# Out:
# /Users/niallgushue/anaconda3/lib/python3.11/site-packages/GushuePhotodecomp.py:296: RuntimeWarning: divide by zero encountered in divide
#   self.linear_chisq = sum(self.linear_residual**2 / np.array(self.std) **2)
# /Users/niallgushue/anaconda3/lib/python3.11/site-packages/GushuePhotodecomp.py:319: RuntimeWarning: divide by zero encountered in divide
#   self.exp_chisq = np.sum(self.exp_residual**2 / np.array(self.std) **2)
# The Catalyst Mass is 6.000000000000227 +/- 0.0 mg
# The Initial Rate Constant is: 5.96e-08
# /Users/niallgushue/anaconda3/lib/python3.11/site-packages/GushuePhotodecomp.py:296: RuntimeWarning: divide by zero encountered in divide
#   self.linear_chisq = sum(self.linear_residual**2 / np.array(self.std) **2)
# /Users/niallgushue/anaconda3/lib/python3.11/site-packages/GushuePhotodecomp.py:319: RuntimeWarning: divide by zero encountered in divide
#   self.exp_chisq = np.sum(self.exp_residual**2 / np.array(self.std) **2)
# ...

# %% [markdown]
# # Read in Old Lamp USR 450

# %%
Decomp_450OW_6mg_1 = Experiment('RD USR 450 6mg 6-20-24.xlsx', 
                        [20.26977,20.26979,20.26884,20.26875,20.26866],
                        [20.27512,20.27517,20.27524,20.27523,20.27515],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
Decomp_450OW_6mg_2 = Experiment('RD USR 450 6mg 6-19-24.xlsx', 
                        [20.53980,20.53985,20.53983,20.53999,20.53987],
                        [20.54586,20.54578,20.54602,20.54625,20.54618],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
Decomp_450OW_6mg_3 = Experiment('LB USR 450 6mg 3-18-24.xlsx', 
                        [20.00000],
                        [20.0059],
                        times = [0, 5, 15, 35, 75,115],
                        avg = False)

Decomp_450OW_10mg_1 = Experiment('RD USR 450 10mg 6-11-24.xlsx', 
                        [20.54258,20.54276,20.54279,20.54282,20.54291],
                        [20.55281,20.55291,20.55303,20.55312,20.55320],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
Decomp_450OW_10mg_2 = Experiment('RD USR 450 10mg 6-10-24.xlsx', 
                        [21.98453,21.98472,21.98500,21.98510,21.98518],
                        [21.99489,21.99497,21.99501,21.99502,21.99507],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
Decomp_450OW_10mg_3 = Experiment('RD USR 450 10mg 6-12-24.xlsx', 
                        [20.26960,20.26948,20.26951,20.26956,20.26952],
                        [20.27939,20.27948,20.27962,20.27968,20.27939],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)

Decomp_450OW_14mg_1 = Experiment('RD USR 450 14mg 6-13-24.xlsx', 
                        [21.98385,21.98419,21.98437,21.98449,21.98458],
                        [21.99833,21.99846,21.99847,21.99854,21.99845],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
Decomp_450OW_14mg_2 = Experiment('RD USR 450 14mg 6-13-24 2.xlsx', 
                        [20.34013,20.34014,20.34011,20.34008,20.34011],
                        [20.35413,20.35416,20.35426,20.35433,20.35444],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
Decomp_450OW_14mg_3 = Experiment('LB USR 450 14mg 10-5-23.xlsx', 
                        [20.00000],
                        [20.01420],
                        times = [0, 5, 15, 35, 75,115],
                        avg = False)

Decomp_450OW_18mg_1 = Experiment('RD USR 450 18mg 6-6-24.xlsx', 
                        [19.70959,19.70962,19.70958,19.70965,19.70966],
                        [19.72738,19.72748,19.72754,19.72763,19.72762],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
Decomp_450OW_18mg_2 = Experiment('RD USR 450 18mg 6-4-24.xlsx', 
                        [19.70935,19.70945,19.70934,19.70948,19.70948],
                        [19.72738,19.72738,19.72738,19.72743,19.72739],
                        times = [0, 5, 15, 35, 75],
                        avg = True)
Decomp_450OW_18mg_3 = Experiment('RD USR 450 18mg 6-7-24.xlsx', 
                        [20.17927,20.17942,20.17944,20.17946,20.17949],
                        [20.19729,20.19741,20.19746,20.19750,20.19756],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)

Decomp_450OW_22mg_1 = Experiment('RD USR 450 22mg 6-14-24.xlsx', 
                        [20.28352,20.28303,20.28298,20.28281,20.28259],
                        [20.30485,20.30476,20.30437,20.30480,20.30464],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
Decomp_450OW_22mg_2 = Experiment('RD USR 450 22mg 6-17-24.xlsx', 
                        [20.34020,20.34020,20.34026,20.34027,20.34030],
                        [20.36226,20.36237,20.36236,20.36234,20.36238],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
Decomp_450OW_22mg_3 = Experiment('RD USR 450 22mg 6-18-24.xlsx', 
                        [21.98461,21.98462,21.98460,21.98459,21.98454],
                        [22.00671,22.00670,22.00684,22.00684,22.00678],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)
# Out:
# The Catalyst Mass is 6.01999999999947 +/- 0.5357984695760739 mg
# The Initial Rate Constant is: 2.90e-08
# The Catalyst Mass is 6.150000000000233 +/- 0.13841965178398188 mg
# The Initial Rate Constant is: 1.53e-07
# The Catalyst Mass is 5.90000000000046 +/- 0.0 mg
# The Initial Rate Constant is: 9.08e-08
# /Users/niallgushue/anaconda3/lib/python3.11/site-packages/GushuePhotodecomp.py:296: RuntimeWarning: divide by zero encountered in divide
#   self.linear_chisq = sum(self.linear_residual**2 / np.array(self.std) **2)
# /Users/niallgushue/anaconda3/lib/python3.11/site-packages/GushuePhotodecomp.py:319: RuntimeWarning: divide by zero encountered in divide
#   self.exp_chisq = np.sum(self.exp_residual**2 / np.array(self.std) **2)
# The Catalyst Mass is 10.242000000000218 +/- 0.053441556864158926 mg
# The Initial Rate Constant is: 1.69e-07
# The Catalyst Mass is 10.086000000000439 +/- 0.18639742487541489 mg
# The Initial Rate Constant is: 2.11e-07
# ...

# %% [markdown]
# # Read in New Lamp USR AR

# %%
Decomp_45AR_22mg_1 = Experiment('W Lamp USR AR New Batch 22mg 7-31-24.xlsx', 
                        [20.18215,20.18212,20.18207,20.18208,20.18202],
                        [20.20418,20.20408,20.20403,20.20407,20.20397],
                        times = [0, 5, 17, 37, 77],
                        avg = True)
# Out:
# The Catalyst Mass is 21.97800000000072 +/- 0.02925747767710226 mg
# The Initial Rate Constant is: 2.28e-07

# %% [markdown]
# # Read in New Lamp USR 450

# %%
Decomp_45NW_6mg_1 = Experiment('W Lamp USR 450 New Batch 6mg 7-22-24.xlsx', 
                        [30.34165,30.34175,30.34176,30.34176,30.34179],
                        [30.34788,30.34788,30.34784,30.34783,30.34789],
                        times = [0, 5, 15, 35, 75,95],
                        MO_stock_conc = 2.903e-5,
                        avg = True)

Decomp_45NW_10mg_1 = Experiment('W Lamp USR 450 New Batch 10mg 7-22-24.xlsx', 
                        [20.54289,20.54287,20.54273,20.54277,20.54286],
                        [20.55299,20.55288,20.55305,20.55286,20.55303],
                        times = [0, 5, 15, 35, 75,115],
                        MO_stock_conc = 2.903e-5,
                        avg = True)

Decomp_45NW_15mg_1 = Experiment('W Lamp USR 450 New Batch 15mg 7-22-24.xlsx', 
                        [20.17975,20.17965,20.17967,20.17968,20.17969],
                        [20.19507,20.19506,20.19508,20.19511,20.19513],
                        times = [0, 5, 15, 35, 75],
                        MO_stock_conc = 2.903e-5,
                        avg = True)

Decomp_45NW_18mg_1 = Experiment('W Lamp USR 450 New Batch 18mg 7-30-24.xlsx', 
                        [20.54237,20.54224,20.54229,20.54227,20.54221],
                        [20.56045,20.56041,20.56039,20.56036,20.56038],
                        times = [0, 5, 15, 35, 75,115],
                        MO_stock_conc = 2.903e-5,
                        avg = True)

Decomp_45NW_22mg_1 = Experiment('W Lamp USR 450 New Batch 22mg 7-31-24.xlsx', 
                        [20.18215,20.18212,20.18207,20.18208,20.18202],
                        [20.20418,20.20408,20.20403,20.20407,20.20397],
                        times = [0, 5, 15, 35, 75,95],
                        MO_stock_conc = 2.903e-5,
                        avg = True)
# Out:
# The Catalyst Mass is 6.1219999999991614 +/- 0.05775811631255634 mg
# The Initial Rate Constant is: 6.48e-08
# The Catalyst Mass is 10.137999999999181 +/- 0.10419213022165982 mg
# The Initial Rate Constant is: 3.39e-08
# The Catalyst Mass is 15.402000000000271 +/- 0.04261455150384513 mg
# The Initial Rate Constant is: 5.07e-08
# The Catalyst Mass is 18.122000000000327 +/- 0.039698866481914626 mg
# The Initial Rate Constant is: 2.08e-07
# The Catalyst Mass is 21.97800000000072 +/- 0.02925747767710226 mg
# The Initial Rate Constant is: 1.04e-07

# %% [markdown]
# # Process Old Lamp USR AR

# %% [markdown]
# ## Concentration vs Time Plots

# %% [markdown]
# ### 6mg 1: Linear

# %%
Decomp_AROW_6mg_1.compare_fit_quality()
Decomp_AROW_6mg_1.plot_linearfit()
Decomp_AROW_6mg_1.plot_ratetime(label = '6mg', plot_title = 'USR AR 6mg Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# exponential fit better
# linear chi squared: inf	 exponential chi squared: inf
# The Linear Fit Equation is: Conc = -1.32e-07*t + 3.28e-05

# %% [markdown]
# ### 12mg 1: Linear

# %%
Decomp_AROW_12mg_1.compare_fit_quality()
Decomp_AROW_12mg_1.plot_linearfit()
Decomp_AROW_12mg_1.plot_ratetime(label = '12mg', plot_title = 'USR AR 12mg Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# exponential fit better
# linear chi squared: inf	 exponential chi squared: inf
# The Linear Fit Equation is: Conc = -2.43e-07*t + 3.32e-05

# %% [markdown]
# ### 23mg 1: Linear

# %%
Decomp_AROW_23mg_1.compare_fit_quality()
Decomp_AROW_23mg_1.plot_linearfit()
Decomp_AROW_12mg_1.plot_ratetime(label = '23mg', plot_title = 'USR AR 23mg Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# exponential fit better
# linear chi squared: inf	 exponential chi squared: inf
# The Linear Fit Equation is: Conc = -2.65e-07*t + 3.27e-05

# %% [markdown]
# ## Mass Dependence Plots

# %% [markdown]
# ### Overrides

# %%
Decomp_AROW_6mg_1.find_initial_rate_constant(override = 0)
Decomp_AROW_12mg_1.find_initial_rate_constant(override = 0)
Decomp_AROW_23mg_1.find_initial_rate_constant(override = 0)
# Out:
# The Initial Rate Constant is: 1.32e-07
# The Initial Rate Constant is: 2.43e-07
# The Initial Rate Constant is: 2.65e-07
# /Users/niallgushue/anaconda3/lib/python3.11/site-packages/GushuePhotodecomp.py:296: RuntimeWarning: divide by zero encountered in divide
#   self.linear_chisq = sum(self.linear_residual**2 / np.array(self.std) **2)

# %% [markdown]
# ### Initial Rate Plot

# %%
experiment_set = Decomp_AROW_6mg_1,Decomp_AROW_12mg_1,Decomp_AROW_23mg_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'Old USR AR Lamp', 
    plot_title = 'Mass Dependence of Old USR AR with Tungsten Lamp \n With Initial Rate Constants')

# %% [markdown]
# # Process Old Lamp USR 450

# %% [markdown]
# ## Concentration vs Time Plots

# %% [markdown]
# ### 6mg 1: Exp

# %%
Decomp_450OW_6mg_1.compare_fit_quality()
Decomp_450OW_6mg_1.plot_expfit()
Decomp_450OW_6mg_1.plot_ratetime(label = '6mg', plot_title = 'USR 450 6mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 4.37e-08	 exponential chi squared: 2.76e-08
# The Exponential Fit Equation is: Conc = 3.24e-05 * exp(-2.70e-03*t)

# %% [markdown]
# ### 6mg 2: Exp

# %%
Decomp_450OW_6mg_2.compare_fit_quality()
Decomp_450OW_6mg_2.plot_expfit()
Decomp_450OW_6mg_2.plot_ratetime(label = '6mg', plot_title = 'USR 450 6mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 6.00e-05	 exponential chi squared: 8.44e-07
# The Exponential Fit Equation is: Conc = 3.39e-05 * exp(-1.40e-02*t)

# %% [markdown]
# ### 6mg 3: Linear

# %%
Decomp_450OW_6mg_3.compare_fit_quality()
Decomp_450OW_6mg_3.plot_expfit()
Decomp_450OW_6mg_3.plot_ratetime(label = '6mg', plot_title = 'USR 450 6mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: inf	 exponential chi squared: inf
# The Exponential Fit Equation is: Conc = 4.09e-05 * exp(-6.77e-03*t)

# %% [markdown]
# ### 10mg 1: Linear

# %%
Decomp_450OW_10mg_1.compare_fit_quality()
Decomp_450OW_10mg_1.plot_expfit()
Decomp_450OW_10mg_1.plot_ratetime(label = '10mg', plot_title = 'USR 450 10mg Concentration vs Time')
# Out:
# linear fit better
# linear chi squared: 2.23e-06	 exponential chi squared: 1.07e-05
# The Exponential Fit Equation is: Conc = 3.43e-05 * exp(-8.29e-03*t)

# %% [markdown]
# ### 10mg 2: Exp

# %%
Decomp_450OW_10mg_2.compare_fit_quality()
Decomp_450OW_10mg_2.plot_expfit()
Decomp_450OW_10mg_2.plot_ratetime(label = '10mg', plot_title = 'USR 450 10mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 2.88e-06	 exponential chi squared: 4.62e-07
# The Exponential Fit Equation is: Conc = 3.65e-05 * exp(-1.82e-02*t)

# %% [markdown]
# ### 10mg 3: Exp

# %%
Decomp_450OW_10mg_3.compare_fit_quality()
Decomp_450OW_10mg_3.plot_expfit()
Decomp_450OW_10mg_3.plot_ratetime(label = '10mg', plot_title = 'USR 450 10mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 1.49e-06	 exponential chi squared: 4.04e-07
# The Exponential Fit Equation is: Conc = 3.24e-05 * exp(-1.06e-02*t)

# %% [markdown]
# ### 14mg 1: Exp

# %%
Decomp_450OW_14mg_1.compare_fit_quality()
Decomp_450OW_14mg_1.plot_expfit()
Decomp_450OW_14mg_1.plot_ratetime(label = '14mg', plot_title = 'USR 450 14mg Concentration vs Time')
# Out:
# linear fit better
# linear chi squared: 1.88e-07	 exponential chi squared: 2.78e-07
# The Exponential Fit Equation is: Conc = 3.30e-05 * exp(-1.20e-02*t)

# %% [markdown]
# ### 14mg 2: Exp

# %%
Decomp_450OW_14mg_2.compare_fit_quality()
Decomp_450OW_14mg_2.plot_expfit()
Decomp_450OW_14mg_2.plot_ratetime(label = '14mg', plot_title = 'USR 450 14mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 1.06e-06	 exponential chi squared: 6.64e-07
# The Exponential Fit Equation is: Conc = 3.35e-05 * exp(-1.21e-02*t)

# %% [markdown]
# ### 14mg 3: Exp

# %%
Decomp_450OW_14mg_3.compare_fit_quality()
Decomp_450OW_14mg_3.plot_expfit()
Decomp_450OW_14mg_3.plot_ratetime(label = '14mg', plot_title = 'USR 450 14mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: inf	 exponential chi squared: inf
# The Exponential Fit Equation is: Conc = 3.32e-05 * exp(-1.04e-02*t)

# %% [markdown]
# ### 18mg 1: Exp

# %%
Decomp_450OW_18mg_1.compare_fit_quality()
Decomp_450OW_18mg_1.plot_expfit()
Decomp_450OW_18mg_1.plot_ratetime(label = '18mg', plot_title = 'USR 450 18mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 6.59e-05	 exponential chi squared: 7.55e-06
# The Exponential Fit Equation is: Conc = 3.25e-05 * exp(-1.31e-02*t)

# %% [markdown]
# ### 18mg 2: Exp

# %%
Decomp_450OW_18mg_2.compare_fit_quality()
Decomp_450OW_18mg_2.plot_expfit()
Decomp_450OW_18mg_2.plot_ratetime(label = '18mg', plot_title = 'USR 450 18mg Concentration vs Time')
# Out:
# linear fit better
# linear chi squared: 3.58e-08	 exponential chi squared: 1.68e-07
# The Exponential Fit Equation is: Conc = 3.62e-05 * exp(-1.28e-02*t)

# %% [markdown]
# ### 18mg 3: Exp

# %%
Decomp_450OW_18mg_3.compare_fit_quality()
Decomp_450OW_18mg_3.plot_expfit()
Decomp_450OW_18mg_3.plot_ratetime(label = '18mg', plot_title = 'USR 450 18mg Concentration vs Time')
# Out:
# linear fit better
# linear chi squared: 7.34e-07	 exponential chi squared: 1.41e-06
# The Exponential Fit Equation is: Conc = 3.28e-05 * exp(-1.42e-02*t)

# %% [markdown]
# ### 22mg 1: Exp

# %%
Decomp_450OW_22mg_1.compare_fit_quality()
Decomp_450OW_22mg_1.plot_expfit()
Decomp_450OW_22mg_1.plot_ratetime(label = '22mg', plot_title = 'USR 450 22mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 6.05e-05	 exponential chi squared: 6.47e-07
# The Exponential Fit Equation is: Conc = 3.40e-05 * exp(-1.40e-02*t)

# %% [markdown]
# ### 22mg 2: Exp

# %%
Decomp_450OW_22mg_2.compare_fit_quality()
Decomp_450OW_22mg_2.plot_expfit()
Decomp_450OW_22mg_2.plot_ratetime(label = '22mg', plot_title = 'USR 450 22mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 1.68e-07	 exponential chi squared: 4.75e-08
# The Exponential Fit Equation is: Conc = 3.31e-05 * exp(-6.75e-03*t)

# %% [markdown]
# ### 22mg 3: Exp

# %%
Decomp_450OW_22mg_3.compare_fit_quality()
Decomp_450OW_22mg_3.plot_expfit()
Decomp_450OW_22mg_3.plot_ratetime(label = '22mg', plot_title = 'USR 450 22mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 2.23e-07	 exponential chi squared: 1.08e-07
# The Exponential Fit Equation is: Conc = 3.33e-05 * exp(-6.69e-03*t)

# %% [markdown]
# ## Mass Dependence Plots

# %% [markdown]
# ### Overrides

# %%
Decomp_450OW_6mg_1.find_initial_rate_constant(override = 1,exp_estimate = 0)
Decomp_450OW_6mg_2.find_initial_rate_constant(override = 1,exp_estimate = 0)
Decomp_450OW_6mg_3.find_initial_rate_constant(override = 1,exp_estimate = 0)
# Out:
# The Initial Rate Constant is: 2.90e-08
# The Initial Rate Constant is: 1.53e-07
# The Initial Rate Constant is: 9.08e-08
# /Users/niallgushue/anaconda3/lib/python3.11/site-packages/GushuePhotodecomp.py:319: RuntimeWarning: divide by zero encountered in divide
#   self.exp_chisq = np.sum(self.exp_residual**2 / np.array(self.std) **2)

# %%
Decomp_450OW_10mg_1.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_450OW_10mg_2.find_initial_rate_constant(override = 1,exp_estimate = 0)
Decomp_450OW_10mg_3.find_initial_rate_constant(override = 1,exp_estimate = 1)
# Out:
# The Initial Rate Constant is: 2.79e-07
# The Initial Rate Constant is: 2.11e-07
# The Initial Rate Constant is: 3.33e-07

# %%
Decomp_450OW_14mg_1.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_450OW_14mg_2.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_450OW_14mg_3.find_initial_rate_constant(override = 1,exp_estimate = 1)
# Out:
# The Initial Rate Constant is: 3.84e-07
# The Initial Rate Constant is: 3.94e-07
# The Initial Rate Constant is: 3.37e-07

# %%
Decomp_450OW_18mg_1.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_450OW_18mg_2.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_450OW_18mg_3.find_initial_rate_constant(override = 1,exp_estimate = 1)
# Out:
# The Initial Rate Constant is: 4.12e-07
# The Initial Rate Constant is: 4.48e-07
# The Initial Rate Constant is: 4.50e-07

# %%
Decomp_450OW_22mg_1.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_450OW_22mg_2.find_initial_rate_constant(override = 1,exp_estimate = 2)
Decomp_450OW_22mg_3.find_initial_rate_constant(override = 1,exp_estimate = 2)
# Out:
# The Initial Rate Constant is: 4.58e-07
# The Initial Rate Constant is: 2.20e-07
# The Initial Rate Constant is: 2.18e-07

# %% [markdown]
# ### Initial Rate Plot

# %%
experiment_set = Decomp_450OW_6mg_1, Decomp_450OW_6mg_2, Decomp_450OW_6mg_3
Decomp_450OW_6mg_Avg = Avg_Experiment(experiment_set)

experiment_set = Decomp_450OW_10mg_1, Decomp_450OW_10mg_2, Decomp_450OW_10mg_3
Decomp_450OW_10mg_Avg = Avg_Experiment(experiment_set)

experiment_set = Decomp_450OW_14mg_1, Decomp_450OW_14mg_2, Decomp_450OW_14mg_3
Decomp_450OW_14mg_Avg = Avg_Experiment(experiment_set)

experiment_set = Decomp_450OW_18mg_1, Decomp_450OW_18mg_2, Decomp_450OW_18mg_3
Decomp_450OW_18mg_Avg = Avg_Experiment(experiment_set)

experiment_set = Decomp_450OW_22mg_1,
Decomp_450OW_22mg_Avg = Avg_Experiment(experiment_set)

experiment_set_OW_Avg = Decomp_450OW_6mg_Avg,Decomp_450OW_10mg_Avg,Decomp_450OW_14mg_Avg,Decomp_450OW_18mg_Avg,Decomp_450OW_22mg_Avg
mass_dependence_of_rate_constant(
    experiment_set_OW_Avg, rate_order = -1, label = 'USR 450', plot_title = 'Mass Dependence of USR 450C with 385nm Light ')
# Out:
# The Average Rate Constant is: Conc = 9.08e-08 +/- 5.05e-08)
# The Average Rate Constant is: Conc = 2.74e-07 +/- 4.97e-08)
# The Average Rate Constant is: Conc = 3.72e-07 +/- 2.51e-08)
# The Average Rate Constant is: Conc = 4.36e-07 +/- 1.76e-08)
# The Average Rate Constant is: Conc = 4.58e-07 +/- 0.00e+00)

# %% [markdown]
# # Process New Lamp AR

# %% [markdown]
# ## Concentration vs Time Plots

# %% [markdown]
# ### 22mg 1: Linear

# %%
Decomp_45AR_22mg_1.compare_fit_quality()
Decomp_45AR_22mg_1.plot_linearfit()
Decomp_45AR_22mg_1.plot_ratetime(label = '22mg', plot_title = 'USR AR 22mg Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# linear fit better
# linear chi squared: 7.84e-08	 exponential chi squared: 1.42e-06
# The Linear Fit Equation is: Conc = -2.28e-07*t + 3.04e-05

# %% [markdown]
# # Process New Lamp 450

# %% [markdown]
# ## Concentration vs Time Plots

# %% [markdown]
# ### 6mg 1: Exp

# %%
Decomp_45NW_6mg_1.compare_fit_quality()
Decomp_45NW_6mg_1.plot_expfit()
Decomp_45NW_6mg_1.plot_ratetime(label = '6mg', plot_title = 'USR AR 6mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 1.17e-06	 exponential chi squared: 1.68e-07
# The Exponential Fit Equation is: Conc = 3.10e-05 * exp(-6.37e-03*t)

# %% [markdown]
# ### 10mg 1: Exp

# %%
Decomp_45NW_10mg_1.compare_fit_quality()
Decomp_45NW_10mg_1.plot_expfit()
Decomp_45NW_10mg_1.plot_ratetime(label = '10mg', plot_title = 'USR AR 10mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 2.39e-06	 exponential chi squared: 1.64e-06
# The Exponential Fit Equation is: Conc = 2.98e-05 * exp(-3.45e-03*t)

# %% [markdown]
# ### 15mg 1: Exp

# %%
Decomp_45NW_15mg_1.compare_fit_quality()
Decomp_45NW_15mg_1.plot_expfit()
Decomp_45NW_15mg_1.plot_ratetime(label = '15mg', plot_title = 'USR AR 15mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 4.69e-06	 exponential chi squared: 2.87e-06
# The Exponential Fit Equation is: Conc = 2.92e-05 * exp(-5.27e-03*t)

# %% [markdown]
# ### 18mg 1: Exp

# %%
Decomp_45NW_18mg_1.compare_fit_quality()
Decomp_45NW_18mg_1.plot_expfit()
Decomp_45NW_18mg_1.plot_ratetime(label = '18mg', plot_title = 'USR AR 18mg Concentration vs Time')
# Out:
# linear fit better
# linear chi squared: 1.67e-05	 exponential chi squared: 6.80e-05
# The Exponential Fit Equation is: Conc = 3.16e-05 * exp(-1.07e-02*t)

# %% [markdown]
# ### 22mg 1: Exp

# %%
Decomp_45NW_22mg_1.compare_fit_quality()
Decomp_45NW_22mg_1.plot_expfit()
Decomp_45NW_22mg_1.plot_ratetime(label = '22mg', plot_title = 'USR AR 22mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 3.42e-06	 exponential chi squared: 4.44e-07
# The Exponential Fit Equation is: Conc = 3.02e-05 * exp(-1.06e-02*t)

# %% [markdown]
# ## Mass Dependence Plots

# %% [markdown]
# ### Overrrides

# %%
Decomp_45NW_6mg_1.find_initial_rate_constant(override = 1,exp_estimate = 2)
Decomp_45NW_10mg_1.find_initial_rate_constant(override = 1,exp_estimate = 2)
Decomp_45NW_15mg_1.find_initial_rate_constant(override = 1,exp_estimate = 2)
Decomp_45NW_18mg_1.find_initial_rate_constant(override = 0,exp_estimate = 2)
Decomp_45NW_22mg_1.find_initial_rate_constant(override = 1,exp_estimate = 2)
# Out:
# The Initial Rate Constant is: 1.85e-07
# The Initial Rate Constant is: 1.00e-07
# The Initial Rate Constant is: 1.53e-07
# The Initial Rate Constant is: 2.08e-07
# The Initial Rate Constant is: 3.06e-07

# %% [markdown]
# ### Initial Rate Plot

# %%
experiment_set = Decomp_45NW_6mg_1,Decomp_45NW_10mg_1,Decomp_45NW_15mg_1,Decomp_45NW_18mg_1,Decomp_45NW_22mg_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'New USR AR Lamp', 
    plot_title = 'Mass Dependence of New USR 450 with Tungsten Lamp \n With Initial Rate Constants')

# %% [markdown]
# # Plot

# %%
plt.plot([10.5,22],[0.9e-7,0.5e-7],'s',label = 'BC, pH = ~5.4', color = 'pink')   
plt.plot([20],[0],'d',label = 'BC, pH = 7', color = 'pink') 

experiment_set = Decomp_450OW_6mg_1, Decomp_450OW_6mg_2, Decomp_450OW_6mg_3
Decomp_450OW_6mg_Avg = Avg_Experiment(experiment_set)

experiment_set = Decomp_450OW_10mg_1, Decomp_450OW_10mg_2, Decomp_450OW_10mg_3
Decomp_450OW_10mg_Avg = Avg_Experiment(experiment_set)

experiment_set = Decomp_450OW_14mg_1, Decomp_450OW_14mg_2, Decomp_450OW_14mg_3
Decomp_450OW_14mg_Avg = Avg_Experiment(experiment_set)

experiment_set = Decomp_450OW_18mg_1, Decomp_450OW_18mg_2, Decomp_450OW_18mg_3
Decomp_450OW_18mg_Avg = Avg_Experiment(experiment_set)

experiment_set = Decomp_450OW_22mg_1,Decomp_450OW_22mg_2,Decomp_450OW_22mg_3
Decomp_450OW_22mg_Avg = Avg_Experiment(experiment_set)

experiment_set = Decomp_AROW_6mg_1,Decomp_AROW_12mg_1,Decomp_AROW_23mg_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'USR AR', 
    plot_title = 'Mass Dependence of USR AR with Tungsten Lamp')

experiment_set_OW_Avg = Decomp_450OW_6mg_Avg,Decomp_450OW_10mg_Avg,Decomp_450OW_14mg_Avg,Decomp_450OW_18mg_Avg,Decomp_450OW_22mg_Avg
mass_dependence_of_rate_constant(
    experiment_set_OW_Avg, rate_order = -1, label = 'USR 450', plot_title = '')

plt.ylim(0 - 4e-9,)

#experiment_set = Decomp_45AR_22mg_1,
#mass_dependence_of_rate_constant(
    #experiment_set, rate_order = -1, label = 'New USR AR', 
    #plot_title = 'Mass Dependence of USR AR with Tungsten Lamp')

#experiment_set = Decomp_45NW_22mg_1,
#mass_dependence_of_rate_constant(
    #experiment_set, rate_order = -1, label = 'New USR 450',) 
    #plot_title = 'Mass Dependence of USR AR with Tungsten Lamp')
# Out:
# The Average Rate Constant is: Conc = 9.08e-08 +/- 5.05e-08)
# The Average Rate Constant is: Conc = 2.74e-07 +/- 4.97e-08)
# The Average Rate Constant is: Conc = 3.72e-07 +/- 2.51e-08)
# The Average Rate Constant is: Conc = 4.36e-07 +/- 1.76e-08)
# The Average Rate Constant is: Conc = 2.99e-07 +/- 1.13e-07)
# (-4e-09, 4.7680538439130035e-07)

# %% [markdown]
# # Decompostion Plots

# %%
Decomp_AROW_6mg_1.plot_linearfit(label = '6mg USR AR', plot_title = '',
                                   color_dot = 'bo', color_line = 'b--')

Decomp_AROW_12mg_1.plot_linearfit(label = '12mg USR AR', plot_title = '',
                                   color_dot = 'ro', color_line = 'r--')

Decomp_AROW_23mg_1.plot_linearfit(label = '23mg USR AR', plot_title = '',
                                   color_dot = 'mo', color_line = 'm--')



#Decomp_SA_AR_30mg_1.plot_linearfit(label = '30mg SA AR', plot_title = '',
                                 # color_dot = 'ro', color_line = 'r--')
#Decomp_30mg_AR_1.plot_linearfit(label = '30mg USR AR', plot_title = '',
                             #  color_dot = 'go', color_line = 'g--')
#Decomp_450_30mg_1.plot_expfit(label = '30mg USR 450', plot_title = '',
                          #  color_dot = 'mo', color_line = 'm--')
# Out:
# The Linear Fit Equation is: Conc = -1.32e-07*t + 3.28e-05
# The Linear Fit Equation is: Conc = -2.43e-07*t + 3.32e-05
# The Linear Fit Equation is: Conc = -2.65e-07*t + 3.27e-05

# %%
Decomp_450OW_6mg_1.plot_expfit(label = '6mg USR 450', plot_title = '',
                                   color_dot = 'bo', color_line = 'b--')

Decomp_450OW_10mg_3.plot_expfit(label = '10mg USR 450', plot_title = '',
                                   color_dot = 'ro', color_line = 'r--')

Decomp_450OW_14mg_2.plot_expfit(label = '14mg USR 450', plot_title = '',
                                   color_dot = 'mo', color_line = 'm--')

Decomp_450OW_18mg_2.plot_expfit(label = '18mg USR 450', plot_title = '',
                                   color_dot = 'yo', color_line = 'y--')

Decomp_450OW_22mg_1.plot_expfit(label = '22mg USR 450', plot_title = '',
                                   color_dot = 'go', color_line = 'g--')

plt.ylim(0,)

plt.legend()
# Out:
# The Exponential Fit Equation is: Conc = 3.24e-05 * exp(-2.70e-03*t)
# The Exponential Fit Equation is: Conc = 3.24e-05 * exp(-1.06e-02*t)
# The Exponential Fit Equation is: Conc = 3.35e-05 * exp(-1.21e-02*t)
# The Exponential Fit Equation is: Conc = 3.62e-05 * exp(-1.28e-02*t)
# The Exponential Fit Equation is: Conc = 3.40e-05 * exp(-1.40e-02*t)
