# %%
from GushuePhotodecomp import *
# Out:
# Analysis performed using Photodecomposotion Analysis Version 3.0 Created by Niall Gushue
#
#       Version 3.0
#       - Major overhaul to organization

# %%
Decomp_5mg_1 = Experiment('385 LED USR AR 5mg 6-13-24.xlsx', 
                        [14.09508,14.09522,14.09518,14.09520,14.09520],
                        [14.10082,14.10088,14.10092,14.10096,14.10092],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_5mg_2 = Experiment('385 LED USR AR 5mg 6-17-24.xlsx', 
                        [14.09535,14.09552,14.09568,14.09570,14.09579],
                        [14.10068,14.10064,14.10070,14.10069,14.10073],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_10mg_1 = Experiment('385 LED USR AR 10mg 6-12-24.xlsx', 
                           [14.10243,14.10268,14.10251,14.10254,14.10239],
                           [14.11300,14.11280,14.11271,14.11267,14.11268], 
                           times = [0, 5, 15, 35, 75],
                           avg = True)

Decomp_15mg_1 = Experiment('385 LED USR AR 15mg 6-12-24.xlsx', 
                         [14.09486,14.09501,14.09515,14.09533,14.09542],
                         [14.10965,14.10964,14.10963,14.10964,14.10969],
                         times = [0, 5, 15, 35, 75],
                         avg = True)

Decomp_15mg_2 = Experiment('385 LED USR AR 15mg 6-17-24.xlsx', 
                           [14.14889,14.14869,14.14847,14.14825,14.14803], 
                           [14.16354,14.16339,14.16331,14.16313,14.16308],
                           times = [0, 5, 15, 35, 75],
                            avg = True)

Decomp_20mg_1 = Experiment('385 LED USR AR 20mg 6-13-24.xlsx', 
                         [14.09877,14.09851,14.09831,14.09837,14.09829],
                         [14.11853,14.11840,14.11845,14.11835,14.11838],
                         times = [0, 5, 15, 35, 75],
                         avg = True)

Decomp_25mg_1 = Experiment('385 LED USR AR 25mg 6-13-24.xlsx', 
                         [14.09927,14.09865,14.09843,14.09838,14.09819],
                         [14.12423,14.12417,14.12416,14.12407,14.12406],
                         times = [0, 5, 15, 35, 75],
                         avg = True)

Decomp_30mg_1 = Experiment('385 LED USR AR 30mg 6-13-24.xlsx', 
                         [14.10371,14.10360,14.10357,14.10338,14.10333],
                         [14.13342,14.13328,14.13326,14.13320,14.13321],
                         times = [0, 5, 15, 35, 75],
                         avg = True)
# Out:
# The Catalyst Mass is 5.7240000000007285 +/- 0.03440930106823073 mg
# The Catalyst Mass is 5.08000000000024 +/- 0.13813037319872506 mg
# The Catalyst Mass is 10.261999999999816 +/- 0.16557777628628018 mg
# The Catalyst Mass is 14.495999999999754 +/- 0.19509997437211501 mg
# The Catalyst Mass is 14.82399999999977 +/- 0.14150618361077172 mg
# The Catalyst Mass is 19.971999999999923 +/- 0.13702554506358977 mg
# The Catalyst Mass is 25.553999999999633 +/- 0.31727590516741855 mg
# The Catalyst Mass is 29.756000000000075 +/- 0.07964923100735195 mg

# %% [markdown]
# # USR AR Decomposition

# %% [markdown]
# ## Decomposition Spectra

# %% [markdown]
# ### 5mg Spectra

# %%
Decomp_5mg_1.plotdecomp(label = '385nm LED 5mg 1', ylim_max = 0.88)

# %%
Decomp_5mg_2.plotdecomp(label = '385nm LED 5mg 2', ylim_max = 0.88)

# %% [markdown]
# ### 10mg Spectra

# %%
Decomp_10mg_1.plotdecomp(label = '385nm LED 10mg', ylim_max = 0.88)

# %% [markdown]
# ### 15mg Spectra

# %%
Decomp_15mg_1.plotdecomp(label = '385nm LED 15mg 1', ylim_max = 0.88)

# %%
Decomp_15mg_2.plotdecomp(label = '385nm LED 15mg 2', ylim_max = 0.88)

# %% [markdown]
# ### 20mg Spectra

# %%
Decomp_20mg_1.plotdecomp(label = '385nm LED 5mg', ylim_max = 0.88)

# %% [markdown]
# ### 25mg Spectra

# %%
Decomp_25mg_1.plotdecomp(label = '385nm LED 5mg', ylim_max = 0.88)

# %% [markdown]
# ### 30mg Spectra

# %%
Decomp_30mg_1.plotdecomp(label = '385nm LED 5mg', ylim_max = 0.88)

# %% [markdown]
# ## Concentration vs Time

# %%
Decomp_5mg_1.plot_ratetime(label = '5mg')
Decomp_10mg_1.plot_ratetime(label = '10mg')
Decomp_15mg_1.plot_ratetime(label = '15mg')
Decomp_20mg_1.plot_ratetime(label = '20mg')
Decomp_25mg_1.plot_ratetime(label = '25mg')
Decomp_30mg_1.plot_ratetime(label = '30mg', plot_title = 'Concentration vs Time')

# %% [markdown]
# ### 5 mg Concentration vs Time

# %%
Decomp_5mg_1.compare_fit_quality()
Decomp_5mg_1.find_exp_rate_constant()
Decomp_5mg_1.plot_expfit()
Decomp_5mg_1.plot_ratetime(label = '5mg', plot_title = 'USR AR 5mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 3.93e-07	 exponential chi squared: 1.87e-07
# The exponential rate constant is 1.381e-02
# The Exponential Fit Equation is: Conc = 3.17e-05 * exp(-1.38e-02*t)

# %%
Decomp_5mg_2.compare_fit_quality()
Decomp_5mg_2.find_exp_rate_constant()
Decomp_5mg_2.plot_expfit()
Decomp_5mg_2.plot_ratetime(label = '5mg', plot_title = '5mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 2.30e-07	 exponential chi squared: 1.92e-08
# The exponential rate constant is 9.818e-03
# The Exponential Fit Equation is: Conc = 3.14e-05 * exp(-9.82e-03*t)

# %% [markdown]
# ### 10 mg Concentration vs Time

# %%
Decomp_10mg_1.compare_fit_quality()
Decomp_10mg_1.find_exp_rate_constant()
Decomp_10mg_1.plot_expfit()
Decomp_10mg_1.plot_ratetime(label = '10mg', plot_title = '10mg Concentration vs Time')
# Out:
# linear fit better
# linear chi squared: 2.23e-07	 exponential chi squared: 3.89e-07
# The exponential rate constant is 1.007e-02
# The Exponential Fit Equation is: Conc = 3.30e-05 * exp(-1.01e-02*t)

# %% [markdown]
# ### 15 mg Concentration vs Time

# %%
Decomp_15mg_1.compare_fit_quality()
Decomp_15mg_1.find_exp_rate_constant()
Decomp_15mg_1.plot_expfit()
Decomp_15mg_1.plot_ratetime(label = '15mg', plot_title = '15mg Concentration vs Time')
# Out:
# linear fit better
# linear chi squared: 6.85e-07	 exponential chi squared: 8.14e-07
# The exponential rate constant is 1.329e-02
# The Exponential Fit Equation is: Conc = 3.14e-05 * exp(-1.33e-02*t)

# %%
Decomp_15mg_2.plot_ratetime(label = '15mg', plot_title = '15mg Concentration vs Time')
Decomp_15mg_2.compare_fit_quality()
Decomp_15mg_2.find_linear_rate_constant()
Decomp_15mg_2.plot_linearfit()
# Out:
# exponential fit better
# linear chi squared: 1.85e-06	 exponential chi squared: 1.74e-06
# The rate constant is: 3.677e-07 +/- -10.87%
# The Linear Fit Equation is: Conc = -3.68e-07*t + 3.03e-05

# %% [raw]
# -Add error bars to the linear fit
# -Choose a value of k and Ao, generating example data at times i have. Make an array
# of the y values as a function of time, fit that data using my data. Look at the k and ao
# values.

# %% [markdown]
# ### 20 mg Concentration vs Time

# %%
Decomp_20mg_1.compare_fit_quality()
Decomp_20mg_1.find_exp_rate_constant()
Decomp_20mg_1.plot_expfit()
Decomp_20mg_1.plot_ratetime(label = '20mg', plot_title = '20mg USR AR Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 1.66e-06	 exponential chi squared: 7.07e-07
# The exponential rate constant is 3.506e-02
# The Exponential Fit Equation is: Conc = 3.50e-05 * exp(-3.51e-02*t)

# %% [markdown]
# ### 25 mg Concentration vs Time

# %%
Decomp_25mg_1.compare_fit_quality()
Decomp_25mg_1.find_exp_rate_constant()
Decomp_25mg_1.plot_expfit()
Decomp_25mg_1.plot_ratetime(label = '25mg', plot_title = '25mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 1.62e-05	 exponential chi squared: 6.80e-06
# The exponential rate constant is 3.710e-02
# The Exponential Fit Equation is: Conc = 3.50e-05 * exp(-3.71e-02*t)

# %% [markdown]
# ### 30 mg Concentration vs Time

# %%
Decomp_30mg_1.plot_ratetime(label = '30mg', plot_title = '30mg Concentration vs Time')
Decomp_30mg_1.compare_fit_quality()
Decomp_30mg_1.find_exp_rate_constant()
Decomp_30mg_1.plot_expfit()
Decomp_30mg_1.find_initial_rate_constant()
# Out:
# linear fit better
# linear chi squared: 4.16e-06	 exponential chi squared: 7.48e-06
# The exponential rate constant is 3.089e-02
# The Exponential Fit Equation is: Conc = 3.37e-05 * exp(-3.09e-02*t)

# %% [markdown]
# ## Mass Plots

# %% [markdown]
# ### Plots

# %% [markdown]
# # USR 450 Decompositon

# %%
Decomp_450_5mg_1 = Experiment('385 LED USR 450 5mg 6-24-24.xlsx', 
                        [14.09569,14.09558,14.09548,14.09553,14.09552],
                        [14.10120,14.10119,14.10121,14.10117,14.10124],
                        times = [0, 5, 15, 35, 75,120],
                        avg = True)

Decomp_450_10mg_1 = Experiment('385 LED USR 450 10mg 6-24-24.xlsx', 
                        [30.52568,30.52567,30.52581,30.52576,30.52573],
                        [30.53674,30.53670,30.53667,30.53668,30.53678],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_450_15mg_1 = Experiment('385 LED USR 450 15mg 6-25-24.xlsx', 
                        [30.52598,30.52599,30.52603,30.52604,30.52596],
                        [30.54080,30.54086,30.54080,30.54082,30.54078],
                        times = [0, 5, 15, 35, 65],
                        avg = True)

Decomp_450_20mg_1 = Experiment('385 LED USR 450 20mg 6-28-24.xlsx', 
                        [14.09533,14.09540,14.09532,14.09528,14.09535],
                        [14.11528,14.11536,14.11537,14.11546,14.11545],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_450_25mg_1 = Experiment('385 LED USR 450 25mg 6-25-24.xlsx', 
                        [14.09538,14.09540,14.09543,14.09528,14.09536],
                        [14.12098,14.12100,14.12108,14.12113,14.12101],
                        times = [0, 5, 15, 35, 65],
                        avg = True)

Decomp_450_30mg_1 = Experiment('385 LED USR 450 30mg 6-28-24.xlsx', 
                        [21.98394,21.98388,21.98385,21.98386,21.98378],
                        [22.01375,22.01374,22.01379,22.01364,22.01385],
                        times = [0, 5, 15, 35, 75],
                        avg = True)
# Out:
# The Catalyst Mass is 5.64200000000028 +/- 0.0803492377059961 mg
# The Catalyst Mass is 10.984000000000549 +/- 0.07964923100631713 mg
# The Catalyst Mass is 14.81200000000058 +/- 0.03544009029199702 mg
# The Catalyst Mass is 20.048000000000243 +/- 0.08657944328738765 mg
# The Catalyst Mass is 25.669999999999856 +/- 0.0927361849550857 mg
# The Catalyst Mass is 29.89200000000025 +/- 0.10419213022183714 mg

# %% [markdown]
# ## Decompositon Spectra

# %% [markdown]
# ### 5mg Spectra

# %%
Decomp_450_5mg_1.plotdecomp(label = '385nm LED 5mg', ylim_max = 0.88)

# %% [markdown]
# ### 10mg Spectra

# %%
Decomp_450_10mg_1.plotdecomp(label = '385nm LED 10mg', ylim_max = 0.88)

# %% [markdown]
# ### 15mg Spectra

# %%
Decomp_450_15mg_1.plotdecomp(label = '385nm LED 10mg', ylim_max = 0.88)

# %% [markdown]
# ### 20mg Spectra

# %%
Decomp_450_20mg_1.plotdecomp(label = '385nm LED 10mg', ylim_max = 0.88)

# %% [markdown]
# ### 25mg Spectra

# %%
Decomp_450_25mg_1.plotdecomp(label = '385nm LED 10mg', ylim_max = 0.88)

# %% [markdown]
# ### 30mg Spectra

# %%
Decomp_450_30mg_1.plotdecomp(label = '385nm LED 10mg', ylim_max = 0.88)

# %% [markdown]
# ## Concentration vs Time

# %% [markdown]
# ### 5 mg Concentration vs Time

# %%
Decomp_450_5mg_1.plot_ratetime(label = '5mg', plot_title = '5mg Concentration vs Time')
Decomp_450_5mg_1.compare_fit_quality()
Decomp_450_5mg_1.find_linear_rate_constant()
Decomp_450_5mg_1.plot_expfit()
Decomp_450_5mg_1.plot_linearfit()
# Out:
# linear fit better
# linear chi squared: 1.10e-07	 exponential chi squared: 6.53e-07
# The rate constant is: 2.036e-07 +/- -0.80%
# The Exponential Fit Equation is: Conc = 3.35e-05 * exp(-1.03e-02*t)
# The Linear Fit Equation is: Conc = -2.04e-07*t + 3.20e-05

# %% [markdown]
# ### 10 mg Concentration vs Time

# %%
Decomp_450_10mg_1.plot_ratetime(label = '10mg', plot_title = '10mg Concentration vs Time')
Decomp_450_10mg_1.compare_fit_quality()
Decomp_450_10mg_1.find_linear_rate_constant()
Decomp_450_10mg_1.plot_linearfit()
# Out:
# linear fit better
# linear chi squared: 2.23e-07	 exponential chi squared: 3.89e-07
# The rate constant is: 2.295e-07 +/- -4.85%
# The Linear Fit Equation is: Conc = -2.30e-07*t + 3.16e-05

# %% [markdown]
# ### 15 mg Concentration vs Time

# %%
Decomp_450_15mg_1.plot_ratetime(label = '15mg', plot_title = '10mg Concentration vs Time')
Decomp_450_15mg_1.compare_fit_quality()
Decomp_450_15mg_1.find_linear_rate_constant()
Decomp_450_15mg_1.plot_linearfit()
# Out:
# linear fit better
# linear chi squared: 2.13e-06	 exponential chi squared: 2.63e-06
# The rate constant is: 3.421e-07 +/- -6.14%
# The Linear Fit Equation is: Conc = -3.42e-07*t + 3.05e-05

# %% [markdown]
# ### 20 mg Concentration vs Time

# %%
Decomp_450_20mg_1.plot_ratetime(label = '20mg', plot_title = '10mg Concentration vs Time')
Decomp_450_20mg_1.compare_fit_quality()
Decomp_450_20mg_1.find_linear_rate_constant()
Decomp_450_20mg_1.plot_linearfit()
# Out:
# exponential fit better
# linear chi squared: 1.23e-05	 exponential chi squared: 7.07e-06
# The rate constant is: 3.375e-07 +/- -8.41%
# The Linear Fit Equation is: Conc = -3.37e-07*t + 2.96e-05

# %% [markdown]
# ### 25 mg Concentration vs Time

# %%
Decomp_450_25mg_1.plot_ratetime(label = '25mg', plot_title = '10mg Concentration vs Time')
Decomp_450_25mg_1.compare_fit_quality()
Decomp_450_25mg_1.find_linear_rate_constant()
Decomp_450_25mg_1.plot_linearfit()
# Out:
# linear fit better
# linear chi squared: 2.45e-05	 exponential chi squared: 9.36e-05
# The rate constant is: 4.541e-07 +/- -11.49%
# The Linear Fit Equation is: Conc = -4.54e-07*t + 3.02e-05

# %% [markdown]
# ### 30 mg Concentration vs Time

# %%
Decomp_450_30mg_1.plot_ratetime(label = '30mg', plot_title = '30mg Concentration vs Time')
Decomp_450_30mg_1.compare_fit_quality()
Decomp_450_30mg_1.find_exp_rate_constant()
Decomp_450_30mg_1.plot_expfit()
# Out:
# exponential fit better
# linear chi squared: 6.23e-05	 exponential chi squared: 1.81e-06
# The exponential rate constant is 3.236e-02
# The Exponential Fit Equation is: Conc = 3.23e-05 * exp(-3.24e-02*t)

# %% [markdown]
# # Total Mass Plots

# %%
experiment_set = Decomp_5mg_2,Decomp_10mg_1,Decomp_15mg_2,Decomp_20mg_1,Decomp_25mg_1,Decomp_30mg_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = 0, label = 'USR AR', plot_title = 'Mass Dependence of USR AR with 385nm Light')

experiment_set = Decomp_450_5mg_1,Decomp_450_10mg_1,Decomp_450_15mg_1,Decomp_450_25mg_1,Decomp_450_20mg_1,Decomp_450_30mg_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = 0, label = 'USR 450', plot_title = 'Mass Dependence of USR AR and 450C with 385nm Light')

# %%
experiment_set = Decomp_450_5mg_1,Decomp_450_10mg_1,Decomp_450_15mg_1,Decomp_450_25mg_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'USR 450', plot_title = 'Mass Dependence of USR AR and 450C with 385nm Light')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
