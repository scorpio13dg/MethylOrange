# %%
 from GushuePhotodecomp import *
# Out:
# Analysis performed using Photodecomposotion Analysis Version 3.0 Created by Niall Gushue
#
#       Version 3.1 - Fixed Calibration Wavelength
#       - Major overhaul to organization

# %% [markdown]
# # Read in SA 450 Data

# %%
Decomp_25mg_SA_450_1 = Experiment('385 LED SA 450 25mg 11-5-24.xlsx', 
                        [4.66431,4.66434,4.66440,4.66439,4.66448],
                        [4.69014,4.69019,4.69019,4.69015,4.69014],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_30mg_SA_450_1 = Experiment('385 LED SA 450 30mg 11-5-24.xlsx', 
                        [5.14782,5.14794,5.14784,5.14795,5.14788],
                        [5.17764,5.17763,5.17768,5.17766,5.17768],
                        times = [0, 5, 15, 35, 75],
                        avg = True)
# Out:
# The Catalyst Mass is 25.778000000000212 +/- 0.06675327707308883 mg
# The Initial Rate Constant is: 1.65e-07
# The Catalyst Mass is 29.77199999999982 +/- 0.06046486583112658 mg
# The Initial Rate Constant is: 1.67e-07

# %% [markdown]
# # Read in SA 500 Data

# %%
Decomp_SA_500_5mg_1 = Experiment('385 LED SA 500 5mg 7-16-24.xlsx', 
                        [4.68521,4.68530,4.68536,4.68534,4.68538],
                        [4.69019,4.69027,4.69025,4.69017,4.69028],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)

Decomp_SA_500_10mg_1 = Experiment('385 LED SA 500 10mg 7-16-24.xlsx', 
                        [5.08792,5.08798,5.08805,5.08809,5.08793],
                        [5.09841,5.09851,5.09858,5.09854,5.09850],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)

Decomp_SA_500_15mg_1 = Experiment('385 LED SA 500 15mg 7-17-24.xlsx', 
                        [5.28802,5.28796,5.28805,5.28807,5.28804],
                        [5.30312,5.30317,5.30306,5.30308,5.30307],
                        times = [0, 5, 15, 35, 65],
                        avg = True)

Decomp_SA_500_20mg_1 = Experiment('385 LED SA 500 20mg 7-17-24.xlsx', 
                        [5.08978,5.08978,5.08971,5.08966,5.08975],
                        [5.10986,5.10982,5.10995,5.11000,5.11004],
                        times = [0, 5, 15, 35, 65],
                        avg = True)

Decomp_SA_500_25mg_1 = Experiment('385 LED SA 500 25mg 7-18-24.xlsx', 
                        [5.00000],
                        [5.02500],
                        times = [0, 5, 15, 35, 95],
                        avg = True)

Decomp_SA_500_30mg_1 = Experiment('385 LED SA 500 30mg 7-18-24.xlsx', 
                        [5.00000],
                        [5.03000],
                        times = [0, 5, 15, 35, 95],
                        avg = True)
# Out:
# The Catalyst Mass is 4.913999999999952 +/- 0.055353410012613624 mg
# The Initial Rate Constant is: 2.77e-08
# The Catalyst Mass is 10.513999999999868 +/- 0.04079215610876565 mg
# The Initial Rate Constant is: 1.34e-07
# The Catalyst Mass is 15.071999999999798 +/- 0.07652450587874304 mg
# The Initial Rate Constant is: 1.84e-07
# The Catalyst Mass is 20.197999999999894 +/- 0.1177115117564294 mg
# The Initial Rate Constant is: 2.89e-07
# The Catalyst Mass is 25.000000000000355 +/- 0.0 mg
# The Initial Rate Constant is: 2.95e-07
# The Catalyst Mass is 30.00000000000025 +/- 0.0 mg
# The Initial Rate Constant is: 3.00e-07

# %% [markdown]
# # Read in SA AR Data

# %%
Decomp_SA_AR_5mg_1 = Experiment('385 LED SA AR 5mg 7-11-24.xlsx', 
                        [20.53997,20.53996,20.53997,20.53992,20.54000],
                        [20.54501,20.54500,20.54509,20.54512,20.54506],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)

Decomp_SA_AR_10mg_1 = Experiment('385 LED SA AR 10mg 7-11-24.xlsx', 
                        [20.54002,20.54010,20.54006,20.54011,20.54014],
                        [20.55081,20.55080,20.55079,20.55086,20.55089],
                        times = [0, 5, 15, 35, 75,115],
                        avg = True)

Decomp_SA_AR_15mg_1 = Experiment('385 LED SA AR 15mg 7-12-24.xlsx', 
                        [4.68533,4.68549,4.68553,4.68551,4.68571],
                        [4.70093,4.70098,4.70110,4.70111,4.70104],
                        times = [0, 5, 15, 35, 65],
                        avg = True)

Decomp_SA_AR_20mg_1 = Experiment('385 LED SA AR 20mg 7-12-24.xlsx', 
                        [30.34179,30.34167,30.34172,30.34171,30.34161],
                        [30.36240,30.36243,30.36243,30.36245,30.36243],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_SA_AR_25mg_1 = Experiment('385 LED SA AR 25mg 7-15-24.xlsx', 
                        [30.34139,30.34137,30.34143,30.34146,30.34151],
                        [30.36742,30.36748,30.36757,30.36759,30.36759],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_SA_AR_30mg_1 = Experiment('385 LED SA AR 30mg 7-15-24.xlsx', 
                        [20.54000,20.54003,20.54012,20.54014,20.54008],
                        [20.57055,20.57067,20.57063,20.57066,20.57067],
                        times = [0, 5, 15, 35, 85],
                        avg = True)
# Out:
# The Catalyst Mass is 5.092000000000496 +/- 0.06144916598312017 mg
# The Initial Rate Constant is: 8.99e-08
# The Catalyst Mass is 10.743999999999687 +/- 0.029393876913542356 mg
# The Initial Rate Constant is: 2.18e-07
# The Catalyst Mass is 15.517999999999967 +/- 0.10225458424932349 mg
# The Initial Rate Constant is: 2.50e-07
# The Catalyst Mass is 20.728000000000435 +/- 0.06910861017222682 mg
# The Initial Rate Constant is: 3.12e-07
# The Catalyst Mass is 26.097999999999644 +/- 0.03969886648302432 mg
# The Initial Rate Constant is: 3.12e-07
# The Catalyst Mass is 30.561999999999756 +/- 0.04791659420242365 mg
# The Initial Rate Constant is: 3.22e-07

# %% [markdown]
# # Read In NG 450 Data

# %%
Decomp_5mg_NG_450_1 = Experiment('385 LED NG 450 5mg 10-7-24.xlsx', 
                        [4.66434,4.66441,4.66440,4.66449,4.66450],
                        [4.66955,4.66948,4.66960,4.66962,4.66948],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_10mg_NG_450_1 = Experiment('385 LED NG 450 10mg 10-7-24.xlsx', 
                        [5.14793,5.14794,5.14786,5.14793,5.14790],
                        [5.15820,5.15829,5.15829,5.15831,5.15826],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_15mg_NG_450_1 = Experiment('385 LED NG 450 15mg 10-7-24.xlsx', 
                        [5.15103,5.15106,5.15112,5.15118,5.15110],
                        [5.16717,5.16705,5.16709,5.16725,5.16704],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_20mg_NG_450_1 = Experiment('385 LED NG 450 20mg 10-7-24.xlsx', 
                        [5.28893,5.28891,5.28885,5.28877,5.28880],
                        [5.30952,5.30950,5.30950,5.30949,5.30953],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_25mg_NG_450_1 = Experiment('385 LED NG 450 25mg 10-1-24.xlsx', 
                        [5.08816,5.08825,5.08820,5.08823,5.08834],
                        [5.11395,5.11402,5.11412,5.11414,5.11430],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_30mg_NG_450_1 = Experiment('385 LED NG 450 30mg 10-1-24.xlsx', 
                        [5.15077,5.15071,5.15070,5.15067,5.15070],
                        [5.18155,5.18164,5.18173,5.18171,5.18178],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_30mg_NG_450_2 = Experiment('385 LED NG 450 30mg 3-25-24.xlsx',
                                  [5.09302,5.09316,5.09307,5.09329,5.09318],
                                  [5.12416,5.12418,5.12436,5.12428,5.12438],
                                  times = [0, 5, 15, 35, 75],
                                  avg = True)

Decomp_25mg_NG_450_2 = Experiment('385 LED NG 450 25mg 3-27-24.xlsx',
                                  [5.0000],#5.29842,5.29852,5.29814,5.29804],
                                  [5.0250],#5.32185,5.32165,5.32199,5.32129],
                                  times = [0, 5, 15, 35, 75],
                                  calibration_wavelength = 466.4,
                                  avg = True)
                                  
Decomp_20mg_NG_450_2 = Experiment('385 LED NG 450 20mg 3-27-24.xlsx',
                                  [5.0000],#5.29842,5.29852,5.29814,5.29804],
                                  [5.0200],#5.32185,5.32165,5.32199,5.32129],
                                  times = [0, 5, 15, 35, 75],
                                  calibration_wavelength = 466.4,
                                  avg = True)

Decomp_15mg_NG_450_2 = Experiment('385 LED NG 450 15mg 3-29-24.xlsx',
                                  [5.0000],#5.29842,5.29852,5.29814,5.29804],
                                  [5.0150],#5.32185,5.32165,5.32199,5.32129],
                                  times = [0, 5, 15, 35, 75],
                                  calibration_wavelength = 466.4,
                                  avg = True)

Decomp_10mg_NG_450_2 = Experiment('385 LED NG 450 10mg 3-29-24.xlsx',
                                  [5.0000],#5.29842,5.29852,5.29814,5.29804],
                                  [5.0100],#5.32185,5.32165,5.32199,5.32129],
                                  times = [0, 5, 15, 35, 75],
                                  calibration_wavelength = 466.4,
                                  avg = True)
# Out:
# The Catalyst Mass is 5.118000000000045 +/- 0.08565045242159759 mg
# The Initial Rate Constant is: 3.85e-08
# The Catalyst Mass is 10.358000000000267 +/- 0.05192301994306883 mg
# The Initial Rate Constant is: 1.84e-07
# The Catalyst Mass is 16.021999999999892 +/- 0.07304792947062126 mg
# The Initial Rate Constant is: 1.21e-07
# The Catalyst Mass is 20.655999999999967 +/- 0.06053098380138433 mg
# The Initial Rate Constant is: 1.71e-07
# The Catalyst Mass is 25.869999999999926 +/- 0.07563068160499326 mg
# The Initial Rate Constant is: 3.23e-07
# The Catalyst Mass is 30.972000000000044 +/- 0.10796295661021488 mg
# The Initial Rate Constant is: 3.29e-07
# The Catalyst Mass is 31.127999999999997 +/- 0.11160645142653051 mg
# The Initial Rate Constant is: 2.96e-07
# The Catalyst Mass is 25.000000000000355 +/- 0.0 mg
# The Initial Rate Constant is: 3.12e-07
# The Catalyst Mass is 19.999999999999574 +/- 0.0 mg
# The Initial Rate Constant is: 2.77e-07
# ...

# %% [markdown]
# # USR Data Read In

# %% [markdown]
# ## USR AR

# %%
Decomp_5mg_AR_1 = Experiment('385 LED USR AR 5mg 6-13-24.xlsx', 
                        [14.09508,14.09522,14.09518,14.09520,14.09520],
                        [14.10082,14.10088,14.10092,14.10096,14.10092],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_5mg_AR_2 = Experiment('385 LED USR AR 5mg 6-17-24.xlsx', 
                        [14.09535,14.09552,14.09568,14.09570,14.09579],
                        [14.10068,14.10064,14.10070,14.10069,14.10073],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_10mg_AR_1 = Experiment('385 LED USR AR 10mg 6-12-24.xlsx', 
                           [14.10243,14.10268,14.10251,14.10254,14.10239],
                           [14.11300,14.11280,14.11271,14.11267,14.11268], 
                           times = [0, 5, 15, 35, 75],
                           avg = True)

Decomp_15mg_AR_1 = Experiment('385 LED USR AR 15mg 6-12-24.xlsx', 
                         [14.09486,14.09501,14.09515,14.09533,14.09542],
                         [14.10965,14.10964,14.10963,14.10964,14.10969],
                         times = [0, 5, 15, 35, 75],
                         avg = True)

Decomp_15mg_AR_2 = Experiment('385 LED USR AR 15mg 6-17-24.xlsx', 
                           [14.14889,14.14869,14.14847,14.14825,14.14803], 
                           [14.16354,14.16339,14.16331,14.16313,14.16308],
                           times = [0, 5, 15, 35, 75],
                            avg = True)

Decomp_20mg_AR_1 = Experiment('385 LED USR AR 20mg 6-13-24.xlsx', 
                         [14.09877,14.09851,14.09831,14.09837,14.09829],
                         [14.11853,14.11840,14.11845,14.11835,14.11838],
                         times = [0, 5, 15, 35, 75],
                         avg = True)

Decomp_25mg_AR_1 = Experiment('385 LED USR AR 25mg 6-13-24.xlsx', 
                         [14.09927,14.09865,14.09843,14.09838,14.09819],
                         [14.12423,14.12417,14.12416,14.12407,14.12406],
                         times = [0, 5, 15, 35, 75],
                         avg = True)

Decomp_30mg_AR_1 = Experiment('385 LED USR AR 30mg 6-13-24.xlsx', 
                         [14.10371,14.10360,14.10357,14.10338,14.10333],
                         [14.13342,14.13328,14.13326,14.13320,14.13321],
                         times = [0, 5, 15, 35, 75],
                         avg = True)
# Out:
# The Catalyst Mass is 5.7240000000007285 +/- 0.03440930106823073 mg
# The Initial Rate Constant is: 1.41e-07
# The Catalyst Mass is 5.08000000000024 +/- 0.13813037319872506 mg
# The Initial Rate Constant is: 1.00e-07
# The Catalyst Mass is 10.261999999999816 +/- 0.16557777628628018 mg
# The Initial Rate Constant is: 2.30e-07
# The Catalyst Mass is 14.495999999999754 +/- 0.19509997437211501 mg
# The Initial Rate Constant is: 2.01e-07
# The Catalyst Mass is 14.82399999999977 +/- 0.14150618361077172 mg
# The Initial Rate Constant is: 3.19e-07
# The Catalyst Mass is 19.971999999999923 +/- 0.13702554506358977 mg
# The Initial Rate Constant is: 3.76e-07
# The Catalyst Mass is 25.553999999999633 +/- 0.31727590516741855 mg
# The Initial Rate Constant is: 3.95e-07
# The Catalyst Mass is 29.756000000000075 +/- 0.07964923100735195 mg
# The Initial Rate Constant is: 3.96e-07

# %% [markdown]
# ## USR 450

# %%
Decomp_450_5mg_1 = Experiment('385 LED USR 450 5mg 6-24-24.xlsx', 
                        [14.09569,14.09558,14.09548,14.09553,14.09552],
                        [14.10120,14.10119,14.10121,14.10117,14.10124],
                        times = [0, 5, 15, 35, 75,120],
                        avg = True)

Decomp_450_10mg_1 = Experiment('385 LED USR 450 10mg 6-24-24.xlsx', 
                        [30.52568,30.52567,30.52581,30.52576,30.52573],
                        [30.53674,30.53670,30.53667,30.53668,30.53678],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_450_15mg_1 = Experiment('385 LED USR 450 15mg 6-25-24.xlsx', 
                        [30.52598,30.52599,30.52603,30.52604,30.52596],
                        [30.54080,30.54086,30.54080,30.54082,30.54078],
                        times = [0, 5, 15, 35, 65],
                        avg = True)

Decomp_450_20mg_1 = Experiment('385 LED USR 450 20mg 6-28-24.xlsx', 
                        [14.09533,14.09540,14.09532,14.09528,14.09535],
                        [14.11528,14.11536,14.11537,14.11546,14.11545],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_450_25mg_1 = Experiment('385 LED USR 450 25mg 6-25-24.xlsx', 
                        [14.09538,14.09540,14.09543,14.09528,14.09536],
                        [14.12098,14.12100,14.12108,14.12113,14.12101],
                        times = [0, 5, 15, 35, 65],
                        avg = True)

Decomp_450_30mg_1 = Experiment('385 LED USR 450 30mg 6-28-24.xlsx', 
                        [21.98394,21.98388,21.98385,21.98386,21.98378],
                        [22.01375,22.01374,22.01379,22.01364,22.01385],
                        times = [0, 5, 15, 35, 70],
                        avg = True)
# Out:
# The Catalyst Mass is 5.64200000000028 +/- 0.0803492377059961 mg
# The Initial Rate Constant is: 2.04e-07
# The Catalyst Mass is 10.984000000000549 +/- 0.07964923100631713 mg
# The Initial Rate Constant is: 2.30e-07
# The Catalyst Mass is 14.81200000000058 +/- 0.03544009029199702 mg
# The Initial Rate Constant is: 3.42e-07
# The Catalyst Mass is 20.048000000000243 +/- 0.08657944328738765 mg
# The Initial Rate Constant is: 2.99e-07
# The Catalyst Mass is 25.669999999999856 +/- 0.0927361849550857 mg
# The Initial Rate Constant is: 4.54e-07
# The Catalyst Mass is 29.89200000000025 +/- 0.10419213022183714 mg
# The Initial Rate Constant is: 3.52e-07

# %% [markdown]
# # NG AR Read In

# %%
Decomp_25mg_NG_AR_1 = Experiment('385 LED NG AR 25mg 10-8-24.xlsx', 
                        [5.28000],
                        [5.305000],
                        times = [0, 5, 15, 35, 75],
                        avg = True)

Decomp_30mg_NG_AR_1 = Experiment('385 LED NG AR 30mg 10-8-24.xlsx', 
                        [5.15077,5.15078,5.15079,5.15075,5.15077],
                        [5.18117,5.18128,5.18130,5.18122,5.18131],
                        times = [0, 5, 15, 35, 75],
                        avg = True)
# Out:
# The Catalyst Mass is 24.999999999999467 +/- 0.0 mg
# The Initial Rate Constant is: 1.66e-07
# The Catalyst Mass is 30.484000000000044 +/- 0.04758150901355406 mg
# The Initial Rate Constant is: 3.57e-07

# %% [markdown]
# # Process NG 450 Data

# %% [markdown]
# ## Concentration vs Time Plots

# %% [markdown]
# ### 5mg 1: Exponential

# %%
Decomp_5mg_NG_450_1.compare_fit_quality()
Decomp_5mg_NG_450_1.plot_expfit()
Decomp_5mg_NG_450_1.plot_ratetime(label = '5mg', plot_title = 'NG 450 5mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 8.77e-08	 exponential chi squared: 6.73e-08
# The Exponential Fit Equation is: Conc = 2.99e-05 * exp(-3.90e-03*t)

# %% [markdown]
# ### 10mg 1: Linear

# %%
Decomp_10mg_NG_450_1.compare_fit_quality()
Decomp_10mg_NG_450_1.plot_expfit()
Decomp_10mg_NG_450_1.plot_ratetime(label = '10mg', plot_title = 'NG 450 10mg Concentration vs Time')
# Out:
# linear fit better
# linear chi squared: 2.27e-07	 exponential chi squared: 3.92e-06
# The Exponential Fit Equation is: Conc = 3.05e-05 * exp(-8.13e-03*t)

# %% [markdown]
# ### 15mg 1: Exponential

# %%
Decomp_15mg_NG_450_1.compare_fit_quality()
Decomp_15mg_NG_450_1.plot_expfit()
Decomp_15mg_NG_450_1.plot_ratetime(label = '15mg', plot_title = 'NG 450 15mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 9.53e-06	 exponential chi squared: 1.32e-06
# The Exponential Fit Equation is: Conc = 3.02e-05 * exp(-1.24e-02*t)

# %% [markdown]
# ### 20mg 1: Exponential

# %%
Decomp_20mg_NG_450_1.compare_fit_quality()
Decomp_20mg_NG_450_1.plot_expfit()
Decomp_20mg_NG_450_1.plot_ratetime(label = '20mg', plot_title = 'NG 450 20mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 1.85e-06	 exponential chi squared: 1.42e-06
# The Exponential Fit Equation is: Conc = 3.15e-05 * exp(-1.70e-02*t)

# %% [markdown]
# ### 25mg 1: Exponential

# %%
Decomp_25mg_NG_450_1.compare_fit_quality()
Decomp_25mg_NG_450_1.plot_expfit()
Decomp_25mg_NG_450_1.plot_ratetime(label = '25mg', plot_title = 'NG 450 25mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 4.33e-06	 exponential chi squared: 1.05e-06
# The Exponential Fit Equation is: Conc = 3.28e-05 * exp(-3.19e-02*t)

# %%
Decomp_25mg_NG_450_2.compare_fit_quality()
Decomp_25mg_NG_450_2.plot_linearfit()
Decomp_25mg_NG_450_2.plot_ratetime(label = '25mg', plot_title = 'NG 450 25mg Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# linear fit better
# linear chi squared: 9.37e-06	 exponential chi squared: 1.45e-04
# The Linear Fit Equation is: Conc = -3.12e-07*t + 2.69e-05

# %% [markdown]
# ### 30mg 1: Linear

# %%
Decomp_30mg_NG_450_1.compare_fit_quality()
Decomp_30mg_NG_450_1.plot_expfit()
Decomp_30mg_NG_450_1.plot_ratetime(label = '30mg', plot_title = 'NG 450 30mg Concentration vs Time')
# Out:
# linear fit better
# linear chi squared: 1.95e-06	 exponential chi squared: 8.17e-06
# The Exponential Fit Equation is: Conc = 3.37e-05 * exp(-2.94e-02*t)

# %%
Decomp_30mg_NG_450_2.compare_fit_quality()
Decomp_30mg_NG_450_2.plot_expfit()
Decomp_30mg_NG_450_2.plot_ratetime(label = '30mg', plot_title = 'NG 450 30mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 1.89e-04	 exponential chi squared: 5.00e-08
# The Exponential Fit Equation is: Conc = 3.43e-05 * exp(-2.77e-02*t)

# %% [markdown]
# ## Process NG AR

# %% [markdown]
# ## Concentration vs Time Plots

# %% [markdown]
# ### 25mg NG AR: Exponential

# %%
Decomp_25mg_NG_AR_1.compare_fit_quality()
Decomp_25mg_NG_AR_1.plot_expfit()
Decomp_25mg_NG_AR_1.plot_ratetime(label = '25mg', plot_title = 'NG 450 25mg Concentration vs Time')
# Out:
# exponential fit better
# linear chi squared: 1.03e-05	 exponential chi squared: 1.02e-06
# The Exponential Fit Equation is: Conc = 3.32e-05 * exp(-1.56e-02*t)

# %% [markdown]
# ### 30mg NG AR: Linear

# %%
Decomp_30mg_NG_AR_1.compare_fit_quality()
Decomp_30mg_NG_AR_1.plot_linearfit()
Decomp_30mg_NG_AR_1.plot_ratetime(label = '25mg', plot_title = 'NG 450 25mg Concentration vs Time')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# linear fit better
# linear chi squared: 1.22e-05	 exponential chi squared: 1.41e-05
# The Linear Fit Equation is: Conc = -3.57e-07*t + 3.33e-05

# %% [markdown]
# ## Mass Dependence Plots

# %% [markdown]
# ### Overrides

# %%
Decomp_5mg_NG_450_1.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_10mg_NG_450_1.find_initial_rate_constant(override = 1,exp_estimate = 2)
Decomp_15mg_NG_450_1.find_initial_rate_constant(override = 1,exp_estimate = 2)
Decomp_20mg_NG_450_1.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_25mg_NG_450_1.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_30mg_NG_450_1.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_30mg_NG_450_2.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_25mg_NG_450_2.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_20mg_NG_450_2.find_initial_rate_constant(override = 1,exp_estimate = 2)
Decomp_15mg_NG_450_2.find_initial_rate_constant(override = 1,exp_estimate = 1)
Decomp_10mg_NG_450_2.find_initial_rate_constant(override = 1,exp_estimate = 2)

Decomp_25mg_NG_AR_1.find_initial_rate_constant(override = 0,exp_estimate = 0)
Decomp_30mg_NG_AR_1.find_initial_rate_constant(override = 0,exp_estimate = 0)
# Out:
# The Initial Rate Constant is: 1.15e-07
# The Initial Rate Constant is: 2.65e-07
# The Initial Rate Constant is: 4.06e-07
# The Initial Rate Constant is: 5.12e-07
# The Initial Rate Constant is: 9.69e-07
# The Initial Rate Constant is: 9.23e-07
# The Initial Rate Constant is: 8.87e-07
# The Initial Rate Constant is: 8.22e-07
# The Initial Rate Constant is: 6.92e-07
# The Initial Rate Constant is: 5.57e-07
# The Initial Rate Constant is: 2.71e-07
# The Initial Rate Constant is: 2.71e-07
# The Initial Rate Constant is: 3.57e-07

# %% [markdown]
# Decomp_5mg_AR_2.find_initial_rate_constant(override = 1)
# Decomp_10mg_AR_1.find_initial_rate_constant(override = 0)
# Decomp_15mg_AR_2.find_initial_rate_constant(override = 1)
# Decomp_20mg_AR_1.find_initial_rate_constant(override = 1)
# Decomp_25mg_AR_1.find_initial_rate_constant(override = 1)
# Decomp_30mg_AR_1.find_initial_rate_constant(override = 0)

# %%
Decomp_450_5mg_1.find_initial_rate_constant(override = 0, exp_estimate = 2)
Decomp_450_10mg_1.find_initial_rate_constant(override = 1, exp_estimate = 2)
Decomp_450_15mg_1.find_initial_rate_constant(override = 1, exp_estimate = 2)
Decomp_450_20mg_1.find_initial_rate_constant(override = 1, exp_estimate = 2)
Decomp_450_25mg_1.find_initial_rate_constant(override = 1, exp_estimate = 2)
Decomp_450_30mg_1.find_initial_rate_constant(override = 1, exp_estimate = 2)
# Out:
# The Initial Rate Constant is: 2.04e-07
# The Initial Rate Constant is: 3.28e-07
# The Initial Rate Constant is: 6.45e-07
# The Initial Rate Constant is: 8.66e-07
# The Initial Rate Constant is: 1.06e-06
# The Initial Rate Constant is: 1.13e-06

# %% [markdown]
# ## NG 450 Plots

# %% [markdown]
# ### Zeroth Order Plots

# %%
experiment_set = Decomp_5mg_NG_450_1,Decomp_10mg_NG_450_1,Decomp_15mg_NG_450_1,Decomp_20mg_NG_450_1,Decomp_25mg_NG_450_1,Decomp_30mg_NG_450_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = 0, label = 'NG 450', plot_title = 'Mass Dependence of NG AR and 450C with 385nm Light')

# %% [markdown]
# ### First Order Plots

# %%
experiment_set = Decomp_5mg_NG_450_1,Decomp_10mg_NG_450_1,Decomp_15mg_NG_450_1,Decomp_20mg_NG_450_1,Decomp_25mg_NG_450_1,Decomp_30mg_NG_450_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = 1, label = 'NG 450', plot_title = 'Mass Dependence of NG AR and 450C with 385nm Light')

# %% [markdown]
# ## NG AR Plots

# %% [markdown]
# # Photocatalysts Plots

# %% [markdown]
# ## Initial Rate Plot

# %%
experiment_set = Decomp_5mg_NG_450_1,Decomp_10mg_NG_450_1,Decomp_15mg_NG_450_1,Decomp_20mg_NG_450_1,Decomp_25mg_NG_450_1,Decomp_30mg_NG_450_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'NG 450', point = '^',
    plot_title = 'Mass Dependence of NG AR and 450C with 385nm Light')

experiment_set = Decomp_30mg_NG_450_2,Decomp_25mg_NG_450_2,Decomp_20mg_NG_450_2,Decomp_15mg_NG_450_2,Decomp_10mg_NG_450_2
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'NG 450 New', point = '^',
    plot_title = 'Mass Dependence of NG AR and 450C with 385nm Light')


experiment_set = Decomp_25mg_NG_AR_1,Decomp_30mg_NG_AR_1,
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, point = 's', label = 'NG AR', plot_title = 'Mass Dependence of NG AR and 450C with 385nm Light')

experiment_set = Decomp_450_5mg_1,Decomp_450_10mg_1,Decomp_450_15mg_1,Decomp_450_25mg_1,Decomp_450_20mg_1,Decomp_450_30mg_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1,point = 'v', label = 'USR 450', plot_title = 'Mass Dependence of 450C with 385nm Light')

experiment_set = Decomp_5mg_AR_2,Decomp_10mg_AR_1,Decomp_15mg_AR_2,Decomp_20mg_AR_1,Decomp_25mg_AR_1,Decomp_30mg_AR_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'USR AR', 
    plot_title = 'Mass Dependence of USR AR, NG AR, USR 450, and NG 450 with 385nm Light')

# %%
experiment_set = Decomp_SA_AR_5mg_1,Decomp_SA_AR_10mg_1, Decomp_SA_AR_15mg_1, Decomp_SA_AR_20mg_1, Decomp_SA_AR_25mg_1, Decomp_SA_AR_30mg_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'SA AR', point = 's',
    plot_title = 'Mass Dependence of USR, NG, SA with 385nm Light')

experiment_set = Decomp_25mg_SA_450_1,Decomp_30mg_SA_450_1,
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'SA 450',
    plot_title = 'Mass Dependence of USR, NG, SA with 385nm Light')

experiment_set = Decomp_SA_500_5mg_1,Decomp_SA_500_10mg_1,Decomp_SA_500_15mg_1,Decomp_SA_500_20mg_1,Decomp_SA_500_25mg_1,Decomp_SA_500_30mg_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'SA 500', 
    plot_title = 'Mass Dependence of Photocatalysts with 385nm Light \n With Initial Rate')

# %%
experiment_set = Decomp_5mg_NG_450_1,Decomp_10mg_NG_450_1,Decomp_15mg_NG_450_1,Decomp_20mg_NG_450_1,Decomp_25mg_NG_450_1,Decomp_30mg_NG_450_1
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'NG 450', point = '^',
    plot_title = 'Mass Dependence of NG AR and 450C with 385nm Light')

experiment_set = Decomp_30mg_NG_450_2,Decomp_25mg_NG_450_2,Decomp_20mg_NG_450_2,Decomp_15mg_NG_450_2,Decomp_10mg_NG_450_2
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, label = 'NG 450 New', point = '^',
    plot_title = 'Mass Dependence of NG AR and 450C with 385nm Light')

experiment_set = Decomp_25mg_NG_AR_1,Decomp_30mg_NG_AR_1,
mass_dependence_of_rate_constant(
    experiment_set, rate_order = -1, point = 's', label = 'NG AR', plot_title = 'Mass Dependence of NG AR and 450C with 385nm Light')
